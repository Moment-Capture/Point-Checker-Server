# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **unzip**

# %%
# %cd /content/drive/MyDrive/순간포착/Colab
# !unzip -qq './yolo_backup/yolov5_231016_2.zip'
# Out:
# /content/drive/MyDrive/순간포착/Colab
# Archive:  yolov5_231016.zip
#    creating: content/drive/MyDrive/순간포착/Colab/content/yolov5/
#   inflating: content/drive/MyDrive/순간포착/Colab/content/yolov5/.dockerignore
#   inflating: content/drive/MyDrive/순간포착/Colab/content/yolov5/CONTRIBUTING.md
#   inflating: content/drive/MyDrive/순간포착/Colab/content/yolov5/.pre-commit-config.yaml
#   inflating: content/drive/MyDrive/순간포착/Colab/content/yolov5/.gitignore
#   inflating: content/drive/MyDrive/순간포착/Colab/content/yolov5/requirements.txt
#   inflating: content/drive/MyDrive/순간포착/Colab/content/yolov5/LICENSE
#   inflating: content/drive/MyDrive/순간포착/Colab/content/yolov5/train.py
#   inflating: content/drive/MyDrive/순간포착/Colab/content/yolov5/benchmarks.py
#    creating: content/drive/MyDrive/순간포착/Colab/content/yolov5/segment/
#   inflating: content/drive/MyDrive/순간포착/Colab/content/yolov5/segment/val.py
# ...

# %% [markdown]
# # **train**

# %%
# %cd /content/drive/MyDrive/순간포착/Colab/yolov5/
# !pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/순간포착/Colab/yolov5
# ...

# %%
# !python train.py --data ../dataset/2021_수능/data.yaml --weights yolov5s.pt --batch 16 --epochs 200 --name qna
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/drive/MyDrive/순간포착/Colab/dataset/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=qna, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 1 commit. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# ...

# %% [markdown]
# # **validation**

# %%
# !python val.py --data ../dataset/2021_수능/data.yaml --img 1280 --weights "./runs/train/qna/weights/best.pt"
# Out:
# val: data=/content/drive/MyDrive/순간포착/Colab/dataset/data.yaml, weights=['./runs/train/qna/weights/best.pt'], batch_size=32, imgsz=1280, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning /content/drive/MyDrive/순간포착/Colab/dataset/labels/val.cache... 44 images, 6 backgrounds, 0 corrupt: 100% 50/50 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [01:51<00:00, 55.68s/it]
#                    all         50        242      0.566      0.698      0.527      0.253
# ...

# %% [markdown]
# # **detect**

# %%
# !python detect.py --img 1280 --weights "./runs/train/qna/weights/best.pt" --source "../dataset/2021_수능/images/detect/2021_수능 (109).jpg"
# Out:
# detect: weights=['/content/drive/MyDrive/순간포착/Colab/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (109).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (109).jpg: 1280x928 (no detections), 1324.9ms
# ...

# %%
# !python detect.py --img 1280 --weights "./runs/train/qna/weights/best.pt" --source "../dataset/2021_수능/images/detect/2021_수능 (110).jpg"
# Out:
# detect: weights=['/content/drive/MyDrive/순간포착/Colab/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (110).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (110).jpg: 1280x928 (no detections), 1145.5ms
# ...

# %%
# !python detect.py --img 1280 --weights "./runs/train/qna/weights/best.pt" --source "../dataset/2021_수능/images/detect/2021_수능 (111).jpg"
# Out:
# detect: weights=['/content/drive/MyDrive/순간포착/Colab/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (111).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (111).jpg: 1280x928 (no detections), 1851.4ms
# ...

# %%
# !python detect.py --img 1280 --weights "./runs/train/qna/weights/best.pt" --source "../dataset/2021_수능/images/detect/2021_수능 (112).jpg"
# Out:
# detect: weights=['/content/drive/MyDrive/순간포착/Colab/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (112).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (112).jpg: 1280x928 1 qna, 1777.2ms
# Speed: 9.3ms pre-process, 1777.2ms inference, 6.4ms NMS per image at shape (1, 3, 1280, 1280)
# ...

# %%
# !python detect.py --img 1280 --weights "./runs/train/qna/weights/best.pt" --source "../dataset/2021_수능/images/detect/2021_수능 (113).jpg"
# Out:
# detect: weights=['/content/drive/MyDrive/순간포착/Colab/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (113).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (113).jpg: 1280x928 (no detections), 1200.9ms
# ...

# %%
# !python detect.py --img 1280 --weights "./runs/train/qna/weights/best.pt" --source "../dataset/2021_수능/images/detect/2021_수능 (114).jpg"
# Out:
# detect: weights=['/content/drive/MyDrive/순간포착/Colab/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (114).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (114).jpg: 1280x928 (no detections), 1508.8ms
# ...

# %%
# !python detect.py --img 1280 --weights "./runs/train/qna/weights/best.pt" --source "../dataset/2021_수능/images/detect/2021_수능 (115).jpg"
# Out:
# detect: weights=['/content/drive/MyDrive/순간포착/Colab/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (115).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (115).jpg: 1280x928 (no detections), 1181.6ms
# ...

# %%
# !python detect.py --img 1280 --weights "./runs/train/qna/weights/best.pt" --source "../dataset/2021_수능/images/detect/2021_수능 (116).jpg"
# Out:
# detect: weights=['/content/drive/MyDrive/순간포착/Colab/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (116).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (116).jpg: 1280x928 (no detections), 1187.2ms
# ...

# %%
# !python detect.py --img 1280 --weights "./runs/train/qna/weights/best.pt" --source "../dataset/2021_수능/images/detect/2021_수능 (117).jpg"
# Out:
# detect: weights=['/content/drive/MyDrive/순간포착/Colab/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (117).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (117).jpg: 1280x928 (no detections), 1828.9ms
# ...

# %%
# !python detect.py --img 1280 --weights "./runs/train/qna/weights/best.pt" --source "../dataset/2021_수능/images/detect/2021_수능 (118).jpg"
# Out:
# detect: weights=['/content/drive/MyDrive/순간포착/Colab/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (118).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (118).jpg: 1280x928 1 qna, 1156.6ms
# Speed: 9.0ms pre-process, 1156.6ms inference, 4.2ms NMS per image at shape (1, 3, 1280, 1280)
# ...

# %%
# !python detect.py --img 1280 --weights "./runs/train/qna/weights/best.pt" --source "../dataset/2021_수능/images/detect/2021_수능 (119).jpg"
# Out:
# detect: weights=['/content/drive/MyDrive/순간포착/Colab/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (119).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (119).jpg: 1280x928 (no detections), 1200.2ms
# ...

# %%
# !python detect.py --img 1280 --weights "./runs/train/qna/weights/best.pt" --source "../dataset/2021_수능/images/detect/2021_수능 (120).jpg"
# Out:
# detect: weights=['/content/drive/MyDrive/순간포착/Colab/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (120).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (120).jpg: 1280x928 2 qnas, 1198.3ms
# Speed: 10.2ms pre-process, 1198.3ms inference, 4.4ms NMS per image at shape (1, 3, 1280, 1280)
# ...

# %%
# !python detect.py --img 1280 --weights "./runs/train/qna/weights/best.pt" --source "../dataset/2021_수능/images/val/2021_수능 (143).jpg"
# Out:
# detect: weights=['/content/drive/MyDrive/순간포착/Colab/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/val/2021_수능 (143).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/val/2021_수능 (143).jpg: 1280x928 4 qnas, 1160.4ms
# Speed: 9.5ms pre-process, 1160.4ms inference, 8.2ms NMS per image at shape (1, 3, 1280, 1280)
# ...

# %%
# !python detect.py --img 1280 --weights "./runs/train/qna/weights/best.pt" --source "../dataset/2021_수능/images/val/2021_수능 (141).jpg"
# Out:
# detect: weights=['./runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/val/2021_수능 (141).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/val/2021_수능 (141).jpg: 1280x928 6 qnas, 1333.2ms
# Speed: 22.9ms pre-process, 1333.2ms inference, 5.5ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp45

# %%
# !python detect.py --img 1280 --weights "./runs/train/qna/weights/best.pt" --source "../dataset/2021_수능images/val/2021_수능 (142).jpg"
# Out:
# detect: weights=['./runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/val/2021_수능 (142).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/val/2021_수능 (142).jpg: 1280x928 2 qnas, 1267.3ms
# Speed: 19.9ms pre-process, 1267.3ms inference, 4.2ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp46

# %%
# !python detect.py --img 1280 --weights "./runs/train/qna/weights/best.pt" --source "../dataset/2021_수능/images/val/2021_수능 (144).jpg"
# Out:
# detect: weights=['./runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/val/2021_수능 (144).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/val/2021_수능 (144).jpg: 1280x928 2 qnas, 1202.5ms
# Speed: 9.4ms pre-process, 1202.5ms inference, 5.9ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp48

# %% [markdown]
# # **save**

# %%
# !zip -r ../yolo_backup/yolov5_231016_2.zip ../yolov5
# Out:
# updating: ../yolov5/ (stored 0%)
# updating: ../yolov5/.dockerignore (deflated 56%)
# updating: ../yolov5/CONTRIBUTING.md (deflated 56%)
# updating: ../yolov5/.pre-commit-config.yaml (deflated 60%)
# updating: ../yolov5/.gitignore (deflated 55%)
# updating: ../yolov5/requirements.txt (deflated 55%)
# updating: ../yolov5/LICENSE (deflated 66%)
# updating: ../yolov5/train.py (deflated 69%)
# updating: ../yolov5/benchmarks.py (deflated 69%)
# updating: ../yolov5/segment/ (stored 0%)
# updating: ../yolov5/segment/val.py (deflated 68%)
# updating: ../yolov5/segment/train.py (deflated 69%)
# updating: ../yolov5/segment/tutorial.ipynb (deflated 75%)
# updating: ../yolov5/segment/predict.py (deflated 70%)
# updating: ../yolov5/CITATION.cff (deflated 31%)
# updating: ../yolov5/val.py (deflated 67%)
# updating: ../yolov5/tutorial.ipynb (deflated 74%)
# updating: ../yolov5/detect.py (deflated 69%)
# updating: ../yolov5/.gitattributes (deflated 4%)
# ...
