# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16003, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 16003 (delta 21), reused 20 (delta 13), pack-reused 15967
# Receiving objects: 100% (16003/16003), 14.66 MiB | 17.68 MiB/s, done.
# Resolving deltas: 100% (10983/10983), done.

# %%
# %cd /content/yolov5/
# !pip install -r requirements.txt
# Out:
# /content/yolov5
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 641.0/641.0 kB 18.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.9 MB/s eta 0:00:00
# ...

# %%
# !python train.py --data /content/drive/MyDrive/순간포착/Colab/dataset/data.yaml --cfg /content/yolov5/models/yolov5s.yaml --weights yolov5s.pt --batch 8 --epochs 200 --name qna
# Out:
# train: weights=yolov5s.pt, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/순간포착/Colab/dataset/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=qna, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python val.py --data "/content/drive/MyDrive/순간포착/Colab/dataset/data.yaml" --img 1280 --weights "/content/yolov5/runs/train/qna/weights/best.pt"
# Out:
# val: data=/content/drive/MyDrive/순간포착/Colab/dataset/data.yaml, weights=['/content/yolov5/runs/train/qna/weights/best.pt'], batch_size=32, imgsz=1280, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning /content/drive/MyDrive/순간포착/Colab/dataset/labels/val.cache... 40 images, 50 backgrounds, 0 corrupt: 100% 90/90 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:17<00:00,  5.93s/it]
#                    all         90        241      0.746      0.232     0.0847     0.0469
# ...

# %%
# !python detect.py --img 1280 --weights "/content/yolov5/runs/train/qna/weights/best.pt" --source "/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (109).jpg"
# Out:
# detect: weights=['/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (109).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (109).jpg: 1280x928 (no detections), 77.9ms
# Speed: 1.4ms pre-process, 77.9ms inference, 0.5ms NMS per image at shape (1, 3, 1280, 1280)
# ...

# %%
# !python detect.py --img 1280 --weights "/content/yolov5/runs/train/qna/weights/best.pt" --source "/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (110).jpg"
# Out:
# detect: weights=['/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (110).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (110).jpg: 1280x928 (no detections), 43.8ms
# Speed: 1.2ms pre-process, 43.8ms inference, 0.4ms NMS per image at shape (1, 3, 1280, 1280)
# ...

# %%
# !python detect.py --img 1280 --weights "/content/yolov5/runs/train/qna/weights/best.pt" --source "/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (111).jpg"
# Out:
# detect: weights=['/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (111).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (111).jpg: 1280x928 (no detections), 43.8ms
# Speed: 1.2ms pre-process, 43.8ms inference, 0.4ms NMS per image at shape (1, 3, 1280, 1280)
# ...

# %%
# !python detect.py --img 1280 --weights "/content/yolov5/runs/train/qna/weights/best.pt" --source "/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (112).jpg"
# Out:
# detect: weights=['/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (112).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (112).jpg: 1280x928 2 qnas, 49.6ms
# Speed: 1.2ms pre-process, 49.6ms inference, 1.6ms NMS per image at shape (1, 3, 1280, 1280)
# ...

# %%
# !python detect.py --img 1280 --weights "/content/yolov5/runs/train/qna/weights/best.pt" --source "/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (113).jpg"
# Out:
# detect: weights=['/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (113).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (113).jpg: 1280x928 2 qnas, 46.7ms
# Speed: 1.2ms pre-process, 46.7ms inference, 1.7ms NMS per image at shape (1, 3, 1280, 1280)
# ...

# %%
# !python detect.py --img 1280 --weights "/content/yolov5/runs/train/qna/weights/best.pt" --source "/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (114).jpg"
# Out:
# detect: weights=['/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (114).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (114).jpg: 1280x928 (no detections), 46.5ms
# Speed: 1.2ms pre-process, 46.5ms inference, 0.4ms NMS per image at shape (1, 3, 1280, 1280)
# ...

# %%
# !python detect.py --img 1280 --weights "/content/yolov5/runs/train/qna/weights/best.pt" --source "/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (115).jpg"
# Out:
# detect: weights=['/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (115).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (115).jpg: 1280x928 (no detections), 50.8ms
# Speed: 1.2ms pre-process, 50.8ms inference, 0.5ms NMS per image at shape (1, 3, 1280, 1280)
# ...

# %%
# !python detect.py --img 1280 --weights "/content/yolov5/runs/train/qna/weights/best.pt" --source "/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (116).jpg"
# Out:
# detect: weights=['/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (116).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (116).jpg: 1280x928 (no detections), 45.6ms
# Speed: 1.2ms pre-process, 45.6ms inference, 0.4ms NMS per image at shape (1, 3, 1280, 1280)
# ...

# %%
# !python detect.py --img 1280 --weights "/content/yolov5/runs/train/qna/weights/best.pt" --source "/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (117).jpg"
# Out:
# detect: weights=['/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (117).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (117).jpg: 1280x928 1 qna, 45.8ms
# Speed: 1.2ms pre-process, 45.8ms inference, 1.5ms NMS per image at shape (1, 3, 1280, 1280)
# ...

# %%
# !python detect.py --img 1280 --weights "/content/yolov5/runs/train/qna/weights/best.pt" --source "/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (118).jpg"
# Out:
# detect: weights=['/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (118).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (118).jpg: 1280x928 3 qnas, 46.6ms
# Speed: 1.2ms pre-process, 46.6ms inference, 1.5ms NMS per image at shape (1, 3, 1280, 1280)
# ...

# %%
# !python detect.py --img 1280 --weights "/content/yolov5/runs/train/qna/weights/best.pt" --source "/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (119).jpg"
# Out:
# detect: weights=['/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (119).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (119).jpg: 1280x928 1 qna, 43.3ms
# Speed: 1.2ms pre-process, 43.3ms inference, 1.5ms NMS per image at shape (1, 3, 1280, 1280)
# ...

# %%
# !python detect.py --img 1280 --weights "/content/yolov5/runs/train/qna/weights/best.pt" --source "/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (120).jpg"
# Out:
# detect: weights=['/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (120).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/detect/2021_수능 (120).jpg: 1280x928 (no detections), 47.4ms
# Speed: 1.2ms pre-process, 47.4ms inference, 0.5ms NMS per image at shape (1, 3, 1280, 1280)
# ...

# %%
# !zip -r /content/drive/MyDrive/순간포착/Colab/yolov5_231013.zip /content/yolov5
# Out:
# updating: content/yolov5/ (stored 0%)
# updating: content/yolov5/.dockerignore (deflated 56%)
# updating: content/yolov5/benchmarks.py (deflated 69%)
# updating: content/yolov5/.github/ (stored 0%)
# updating: content/yolov5/.github/ISSUE_TEMPLATE/ (stored 0%)
# updating: content/yolov5/.github/ISSUE_TEMPLATE/config.yml (deflated 49%)
# updating: content/yolov5/.github/ISSUE_TEMPLATE/question.yml (deflated 57%)
# updating: content/yolov5/.github/ISSUE_TEMPLATE/bug-report.yml (deflated 60%)
# updating: content/yolov5/.github/ISSUE_TEMPLATE/feature-request.yml (deflated 61%)
# updating: content/yolov5/.github/dependabot.yml (deflated 60%)
# updating: content/yolov5/.github/workflows/ (stored 0%)
# updating: content/yolov5/.github/workflows/translate-readme.yml (deflated 47%)
# updating: content/yolov5/.github/workflows/codeql-analysis.yml (deflated 51%)
# updating: content/yolov5/.github/workflows/docker.yml (deflated 66%)
# ...

# %%
# !python detect.py --img 1280 --weights "/content/yolov5/runs/train/qna/weights/best.pt" --source "/content/drive/MyDrive/순간포착/Colab/dataset/images/val/2021_수능 (127).jpg"
# Out:
# detect: weights=['/content/yolov5/runs/train/qna/weights/best.pt'], source=/content/drive/MyDrive/순간포착/Colab/dataset/images/val/2021_수능 (127).jpg, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/drive/MyDrive/순간포착/Colab/dataset/images/val/2021_수능 (127).jpg: 1280x928 3 qnas, 46.4ms
# Speed: 1.2ms pre-process, 46.4ms inference, 1.5ms NMS per image at shape (1, 3, 1280, 1280)
# ...
