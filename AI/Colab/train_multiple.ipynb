# %% [markdown]
# # **drive mount**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics/
# !pip install -U ultralytics

from ultralytics import YOLO
# Out:
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.3/709.3 kB 7.3 MB/s eta 0:00:00
# ...

# %%
# !pip install -U ultralytics

# %% [markdown]
# # **requirements**

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.1/78.2 GB disk)

# %%
# %cd /content/drive/MyDrive/순간포착/Colab
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 16974, done.
# remote: Counting objects: 100% (688/688), done.
# remote: Compressing objects: 100% (528/528), done.
# remote: Total 16974 (delta 361), reused 277 (delta 159), pack-reused 16286
# Receiving objects: 100% (16974/16974), 9.29 MiB | 10.94 MiB/s, done.
# Resolving deltas: 100% (11662/11662), done.
# Updating files: 100% (450/450), done.

# %% [markdown]
# # **unzip**

# %%
# %cd /content/drive/MyDrive/순간포착/Colab
# !unzip -qq './yolo_backup/yolov8_231020.zip'
# Out:
# /content/drive/MyDrive/순간포착/Colab

# %% [markdown]
# # **train**

# %% [markdown]
# ##**처음 train**

# %%
from ultralytics.data.utils import autosplit

autosplit(path='../dataset/crop/2021_수능_crop/images')
# Out:
# Autosplitting images from ../dataset/crop/2021_수능_crop/images
# 100%|██████████| 676/676 [00:01<00:00, 379.84it/s]

# %% [markdown]
# ### **train1**

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics
# Out:
# /content/drive/.shortcut-targets-by-id/1F2h4dTE5AEwzXuzoGz7DGAYLmbHrwkX9/MomentCapture/Colab/ultralytics

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')
results = model.train(
    data='../dataset/crop/2021_수능_crop/data.yaml',
    batch=20,
    epochs=50,
    name='crop_train1_epoch50')
# Out:
# New https://pypi.org/project/ultralytics/8.0.208 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### **train2**

# %%
# %cd /content/drive/MyDrive/순간포착/Colab/ultralytics

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')
results = model.train(
    data='../dataset/crop/2021_수능_crop/data.yaml',
    batch=20,
    epochs=100,
    name='crop_train1_epoch100')
# Out:
# New https://pypi.org/project/ultralytics/8.0.207 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## **transfer train**

# %% [markdown]
# ### **train**

# %%
from ultralytics import YOLO

model = YOLO('./runs/detect/train3_qna_2021-수능_epoch100/weights/best.pt')
results = model.train(
    data='../dataset/crop/data.yaml',
    batch=20,
    epochs=100,
    name='crop_train4_qna_2021-수능_2021-9월_epoch100')

# %% [markdown]
# # **validation**

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics/
# Out:
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics

# %%
import chardet

with open('../dataset/crop/2021_수능_crop/autosplit_val.txt', 'rb') as rawdata:
    result = chardet.detect(rawdata.read(10000))

# check what the character encoding might be
print(result)
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %% [markdown]
# ## **train1**

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/crop_train1_epoch50/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val(data='../dataset/crop/2021_수능_crop/data.yaml', name='crop_val_train1')  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25844392 parameters, 0 gradients, 78.7 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 23.2MB/s]
# val: Scanning /content/drive/MyDrive/MomentCapture/Colab/dataset/crop/2021_수능_crop/labels... 72 images, 0 backgrounds, 0 corrupt: 100%|██████████| 72/72 [01:04<00:00,  1.11it/s]
# val: New cache created: /content/drive/MyDrive/MomentCapture/Colab/dataset/crop/2021_수능_crop/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:09<00:00,  1.89s/it]
#                    all         72        486      0.973       0.97       0.97      0.624
#                    num         72         71      0.983      0.986      0.986      0.625
#                     a1         72         70      0.969      0.957      0.958      0.646
# ...

# %% [markdown]
# ## **train2**

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/qna_train2/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val(data='../dataset/crop/data.yaml', name='val_train2_2021-수능')  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/qna_train2/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val(data='../dataset/crop/data.yaml', name='val_train2_2021-9월')  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category

# %% [markdown]
# # **detect**

# %%
# %cd /content/drive/MyDrive/순간포착/Colab/ultralytics/
# Out:
# /content/drive/MyDrive/순간포착/Colab/ultralytics

# %% [markdown]
# ## **train1**

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/crop_train1_qna_2021-수능-crop_epoch50/weights/best.pt')  # pretrained YOLOv8n model

# Run batched inference on a list of images
results = model(source='../dataset/2021_수능_crop/images/detect/', save=True, name='crop_detect_train1_2021-수능', save_crop=True)  # return a generator of Results objects

# Process results generator
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs

# %% [markdown]
# ### **multiple**

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/crop_train1_epoch50/weights/best.pt')  # pretrained YOLOv8n model

# Run batched inference on a list of images
results = model(source='./runs/detect/categorize_detect_train1/crops/multiple', save=True, name='crop_detect_train1_categorize_multiple', save_crop=True)  # return a generator of Results objects

# Process results generator
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
# Out:
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/245 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/runs/detect/categorize_detect_train1/crops/multiple/2021_09 (100).jpg: 640x576 1 num, 1 a1, 1 a2, 1 a3, 1 a4, 1 a5, 1 checked, 71.7ms
# image 2/245 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/runs/detect/categorize_detect_train1/crops/multiple/2021_09 (100)2.jpg: 608x640 1 num, 1 a1, 1 a2, 1 a3, 1 a4, 1 a5, 1 checked, 75.0ms
# image 3/245 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/runs/detect/categorize_detect_train1/crops/multiple/2021_09 (100)3.jpg: 448x640 1 num, 1 a1, 1 a2, 1 a3, 2 a4s, 1 a5, 1 checked, 179.9ms
# image 4/245 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/runs/detect/categorize_detect_train1/crops/multiple/2021_09 (100)4.jpg: 640x640 1 num, 1 a1, 1 a2, 1 a3, 1 a4, 1 a5, 1 checked, 41.8ms
# ...

# %% [markdown]
# ### **multiple_cropped**

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/crop_train1_epoch50/weights/best.pt')  # pretrained YOLOv8n model

# Run batched inference on a list of images
results = model(source='./runs/detect/categorize_detect_train1/crops/multiple_cropped', save=True, name='crop_detect_train1_categorize_multiple_cropped', save_crop=True)  # return a generator of Results objects

# Process results generator
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
# Out:
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/runs/detect/categorize_detect_train1/crops/multiple_cropped/2021_suneung (118).jpg: 192x640 1 a4, 1 a5, 17.2ms
# Speed: 1.1ms preprocess, 17.2ms inference, 1.3ms postprocess per image at shape (1, 3, 192, 640)
# Results saved to /content/drive/MyDrive/MomentCapture/Colab/ultralytics/runs/detect/crop_detect_train1_categorize_multiple_cropped2

# %% [markdown]
# ## **train2**

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/train2_qna_2021-수능_2021-9월_epoch50/weights/best.pt')  # pretrained YOLOv8n model

# Run batched inference on a list of images
results = model(source='../dataset/2021_수능/images/detect/', save=True, name='detect_train2_2021_수능', save_crop=True)  # return a generator of Results objects

# Process results generator
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs

# %% [markdown]
# # **save**

# %%
# !zip -r ../yolo_backup/yolov8_231020.zip ../ultralytics
# Out:
# Scanning files ..
#   adding: ../ultralytics/ (stored 0%)
#   adding: ../ultralytics/.git/ (stored 0%)
#   adding: ../ultralytics/.git/info/ (stored 0%)
#   adding: ../ultralytics/.git/info/exclude (deflated 28%)
#   adding: ../ultralytics/.git/branches/ (stored 0%)
#   adding: ../ultralytics/.git/description (deflated 14%)
#   adding: ../ultralytics/.git/hooks/ (stored 0%)
#   adding: ../ultralytics/.git/hooks/post-update.sample (deflated 27%)
#   adding: ../ultralytics/.git/hooks/update.sample (deflated 68%)
#   adding: ../ultralytics/.git/hooks/pre-push.sample (deflated 49%)
#   adding: ../ultralytics/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: ../ultralytics/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: ../ultralytics/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: ../ultralytics/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: ../ultralytics/.git/hooks/pre-commit.sample (deflated 45%)
# ...
