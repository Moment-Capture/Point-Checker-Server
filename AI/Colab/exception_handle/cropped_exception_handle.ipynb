# %% [markdown]
# # **drive mount**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics/
# !pip install -U ultralytics

from ultralytics import YOLO
# Out:
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.10/dist-packages (8.1.8)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.23.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.1.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.16.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2023.11.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)

# %% [markdown]
# # **requirements**

# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.16.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
# !pip install -U ultralytics

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.1/78.2 GB disk)

# %%
# %cd /content/drive/MyDrive/순간포착/MomentCapture
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 16974, done.
# remote: Counting objects: 100% (688/688), done.
# remote: Compressing objects: 100% (528/528), done.
# remote: Total 16974 (delta 361), reused 277 (delta 159), pack-reused 16286
# Receiving objects: 100% (16974/16974), 9.29 MiB | 10.94 MiB/s, done.
# Resolving deltas: 100% (11662/11662), done.
# Updating files: 100% (450/450), done.

# %% [markdown]
# # **main**

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics
# Out:
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics

# %%
import torch
from torchvision import transforms
from PIL import Image
from ultralytics import YOLO

# %%
import torch
from torchvision import transforms
from PIL import Image

# YOLOv8를 초기화하고 모델을 로드하는 부분은 생략되었다고 가정합니다.

# 예외 처리를 위한 함수 정의
def process_exceptional_object(obj):
    # 특정 클래스의 경우 크기 확대 등 특별한 처리 수행
    obj["processed_image"] = transforms.functional.resize(obj["cropped_image"], (2 * obj["cropped_image"].size[1], 2 * obj["cropped_image"].size[0]))
    return obj

# 이미지 로드 및 전처리
image_path = "path/to/image.jpg"
image = Image.open(image_path).convert("RGB")

# YOLOv8로 객체 감지
with torch.no_grad():
    results = model(image)

# 예외 처리할 클래스
exceptional_class = "person"

# 감지 결과 분석 및 예외 처리
detected_objects = []

for result in results.xyxy[0]:
    class_id = int(result[5])
    confidence = result[4].item()

    if confidence > 0.5:  # 예측 신뢰도가 일정 수준 이상인 경우
        if class_id == class_id_of_exceptional_class:  # 특정 클래스인 경우
            # 예외 처리 수행
            obj = {
                "class": class_id,
                "confidence": confidence,
                "bounding_box": result[0:4].tolist(),
                # 추가 필요한 정보들...
            }
            obj["cropped_image"] = transforms.functional.crop(image, int(obj["bounding_box"][1]), int(obj["bounding_box"][0]),
                                                                int(obj["bounding_box"][3] - obj["bounding_box"][1]), int(obj["bounding_box"][2] - obj["bounding_box"][0]))
            processed_obj = process_exceptional_object(obj)
        else:
            # 일반적인 경우
            processed_obj = {
                "class": class_id,
                "confidence": confidence,
                "bounding_box": result[0:4].tolist(),
                # 추가 필요한 정보들...
            }
            processed_obj["cropped_image"] = transforms.functional.crop(image, int(processed_obj["bounding_box"][1]), int(processed_obj["bounding_box"][0]),
                                                                         int(processed_obj["bounding_box"][3] - processed_obj["bounding_box"][1]), int(processed_obj["bounding_box"][2] - processed_obj["bounding_box"][0]))

        detected_objects.append(processed_obj)

# 예외 처리가 끝난 후, 모든 객체를 하나의 이미지로 이어붙이기
output_path = "path/to/concatenated_image.jpg"
concatenate_images([obj["cropped_image"] for obj in detected_objects], output_path)

# %% [markdown]
# ## **detect**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.1.27-py3-none-any.whl (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.2/721.2 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.17.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 37.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 58.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 65.1 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/nvidia-cublas-cu12/
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.7 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.6 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.1 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.9 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.4 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.2 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, thop, ultralytics
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 thop-0.1.1.post2209072238 ultralytics-8.1.27

# %%
ultralytics_path = "/content/drive/MyDrive/MomentCapture/Colab/ultralytics"
# %cd ultralytics_path
# Out:
# [Errno 2] No such file or directory: 'ultralytics_path'
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics

# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO
import cv2
import os
import time
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path
from google.colab.patches import cv2_imshow
from IPython.display import Image
from ultralytics.utils.plotting import Annotator, colors
from natsort import os_sorted

def croppedBox(box):
    obj = img[int(box[1]):int(box[3]), int(box[0]):int(box[2])]
    return obj

def concatImage(crop_obj, searching_obj):
    max_width = 0
    total_height = crop_obj.shape[0] + searching_obj.shape[0]
    if (crop_obj.shape[1] > searching_obj.shape[1]):
        max_width = crop_obj.shape[1]
    else:
        max_width = searching_obj.shape[1]

    final_obj = np.zeros((total_height, max_width, 3), dtype=np.uint8)
    final_obj.fill(255)
    current_y = 0

    final_obj[current_y:crop_obj.shape[0]+current_y,:crop_obj.shape[1],:] = crop_obj
    current_y += crop_obj.shape[0]

    final_obj[current_y:searching_obj.shape[0]+current_y,:searching_obj.shape[1],:] = searching_obj
    current_y += searching_obj.shape[0]

    return final_obj



colab_path = "/content/drive/MyDrive/MomentCapture/Colab"

ultralytics_path = colab_path + "/ultralytics"

data_source= colab_path + "/dataset/test/naeshin_test"

folder_dir = data_source
images = os_sorted(Path(folder_dir).glob('*.jpg'))

os.chdir(folder_dir)

idx_img = 0
cropped_arr = []

for image in images:
    model = YOLO(ultralytics_path + '/runs/detect/categorize_train5_epoch50/weights/best.pt')
    # results = model(source=image, conf=0.5, save=False, save_crop=False, name='test')
    # results = model(source=image, conf=0.5, save=True, save_crop=True, name='test')
    results = model(source=image, conf=0.7, save=False, save_crop=False, name='test')

    folder_dir = data_source
    images = Path(folder_dir).glob('*.jpg')

    filename = os.path.basename(image)
    # print(filename)
    img = cv2.imread(filename)
    # cv2_imshow(img)

    idx_b = 0
    names = model.names

    for result in results:
        boxes = result.boxes.xyxy.tolist()
        clss = result.boxes.cls.cpu().tolist()

        cropped_arr = []

        if boxes is not None:
            for box, cls in zip(boxes, clss):
                qna = croppedBox(box)

                ###### 확인 ######
                # 필요 없는 정보 제외
                if (names[int(cls)] == "q_mark" or names[int(cls)] == "q_period" or names[int(cls)] == "s_period"):
                    continue
                if (names[int(cls)] == "multiple"):
                    continue

                print()
                print("####")
                # print(idx_b)
                # print(names[int(cls)])
                # print(box)
                # cv2_imshow(qna)
                ###### 확인 ######


                ###### crop 처리 ######
                if (names[int(cls)] == "multiple_cropped"):
                    # print("-- crop 색출 --")
                    print()
                    crop_obj = qna

                    # cropped_arr에 저장된 crop_obj 매칭
                    model_match = YOLO(ultralytics_path + "/runs/detect/matching_train1_epoch50/weights/best.pt")
                    results_match = model_match(source=crop_obj, conf=0.4, save=False)
                    names_match = model_match.names
                    result_match = results_match[0]

                    boxes_match = result_match.boxes.xyxy.tolist()
                    clss_match = result_match.boxes.cls.cpu().tolist()

                    name_match = ""
                    name_search = ""
                    forb = ""

                    # cropped_arr에 crop_obj 유형 정보 추가해서 저장
                    print("")
                    name_crop_arr = []
                    if boxes_match is not None:
                        for box_match, cls_match in zip(boxes_match, clss_match):
                            print(name_match)
                            name_match = names_match[int(cls_match)]
                            name_crop_arr = [name_match, crop_obj]
                            cropped_arr.append(name_crop_arr)
                            # print("삽입\n")

                    if name_match == "front_5" or name_match == "back_5" or name_match == "":
                        continue
                    elif name_match == "front_num":
                        forb = "f"
                        name_search = "back_num"
                    elif name_match == "front_1":
                        forb = "f"
                        name_search = "back_1"
                    elif name_match == "front_2":
                        forb = "f"
                        name_search = "back_2"
                    elif name_match == "front_3":
                        forb = "f"
                        name_search = "back_3"
                    elif name_match == "front_4":
                        forb = "f"
                        name_search = "back_4"
                    elif name_match == "back_num":
                        forb = "b"
                        name_search = "front_num"
                        forb = "b"
                    elif name_match == "back_1":
                        forb = "b"
                        name_search = "front_1"
                    elif name_match == "back_2":
                        forb = "b"
                        name_search = "front_2"
                    elif name_match == "back_3":
                        forb = "b"
                        name_search = "front_3"
                    elif name_match == "back_4":
                        forb = "b"
                        name_search = "front_4"

                    # print(name_search + "\n")
                    # print("검색\n")
                    for i in range(len(cropped_arr)-1):
                        searching_arr = cropped_arr[i]
                        searching_name = searching_arr[0]
                        searching_obj = searching_arr[1]
                        # print(searching_name)
                        if (searching_name == name_search):
                            # 이미지 이어붙이기
                            # joined_image = cv2.vconcat( [crop_obj, searching_obj])
                            if (forb == "f"):
                                joined_image = concatImage(crop_obj, searching_obj)
                            else:
                                joined_image = concatImage(searching_obj, crop_obj)
                            cv2_imshow(joined_image)
                            cropped_arr.remove(name_crop_arr)
                            cropped_arr.remove(searching_arr)
                            break
                    # print()
                    # print("-- crop 색출 --")
                print("####")
                ###### crop 처리 ######

                idx_b += 1
                print()
            print()

    idx_img += 1

print("끝")

os.chdir(ultralytics_path)
# Out:
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (3)-1.jpg: 640x480 (no detections), 28.2ms
# Speed: 3.7ms preprocess, 28.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (3)-2.jpg: 640x480 1 multiple, 2 multiple_croppeds, 2 q_marks, 27.7ms
# Speed: 2.4ms preprocess, 27.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# 0: 416x640 1 back_num, 27.0ms
# Speed: 2.1ms preprocess, 27.0ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
# ####
#
#
# ####
# 0: 96x640 1 front_num, 13.2ms
# Speed: 0.6ms preprocess, 13.2ms inference, 1.3ms postprocess per image at shape (1, 3, 96, 640)
# <PIL.Image.Image image mode=RGB size=530x394>
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (3)-3.jpg: 640x480 (no detections), 27.9ms
# Speed: 2.5ms preprocess, 27.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (3)-4.jpg: 640x480 1 multiple, 1 multiple_cropped, 2 q_marks, 27.8ms
# Speed: 2.4ms preprocess, 27.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# 0: 192x640 1 front_2, 16.9ms
# Speed: 0.9ms preprocess, 16.9ms inference, 1.3ms postprocess per image at shape (1, 3, 192, 640)
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (3)-5.jpg: 640x480 1 multiple, 1 multiple_cropped, 1 q_mark, 27.9ms
# Speed: 2.5ms preprocess, 27.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# 0: 256x640 1 back_2, 18.2ms
# Speed: 1.1ms preprocess, 18.2ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 640)
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (3)-6.jpg: 640x480 1 multiple, 2 multiple_croppeds, 1 subjective, 2 q_marks, 27.9ms
# Speed: 2.4ms preprocess, 27.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# ####
#
#
# ####
# 0: 160x640 1 front_1, 16.0ms
# Speed: 0.9ms preprocess, 16.0ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 640)
# ####
#
#
# ####
# 0: 224x640 1 back_1, 17.7ms
# Speed: 1.0ms preprocess, 17.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 640)
# <PIL.Image.Image image mode=RGB size=538x285>
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (3)-7.jpg: 640x480 1 multiple, 1 q_mark, 27.9ms
# Speed: 2.5ms preprocess, 27.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (3)-8.jpg: 640x480 1 multiple, 1 subjective, 1 q_mark, 1 s_period, 27.8ms
# Speed: 2.5ms preprocess, 27.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (3)-9.jpg: 640x480 3 multiples, 3 q_marks, 27.9ms
# Speed: 2.4ms preprocess, 27.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (3)-10.jpg: 640x480 3 multiples, 3 q_marks, 28.0ms
# Speed: 2.6ms preprocess, 28.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (3)-11.jpg: 640x480 1 multiple_cropped, 1 q_mark, 27.8ms
# Speed: 2.4ms preprocess, 27.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# 0: 160x640 1 front_1, 16.5ms
# Speed: 1.1ms preprocess, 16.5ms inference, 1.9ms postprocess per image at shape (1, 3, 160, 640)
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (3)-12.jpg: 640x480 1 multiple, 1 multiple_cropped, 1 q_mark, 28.4ms
# Speed: 3.9ms preprocess, 28.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
# ####
# 0: 352x640 1 back_1, 25.3ms
# Speed: 2.1ms preprocess, 25.3ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (3)-13.jpg: 640x480 1 multiple, 1 subjective, 2 q_marks, 28.4ms
# Speed: 3.5ms preprocess, 28.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# ####
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (3)-14.jpg: 640x480 3 multiples, 3 q_marks, 27.8ms
# Speed: 2.5ms preprocess, 27.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (4)-1.jpg: 640x480 (no detections), 28.1ms
# Speed: 2.4ms preprocess, 28.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (4)-2.jpg: 640x480 2 multiples, 1 subjective, 2 q_marks, 1 s_period, 27.9ms
# Speed: 2.5ms preprocess, 27.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (4)-3.jpg: 640x480 1 multiple, 1 q_mark, 27.9ms
# Speed: 2.4ms preprocess, 27.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (4)-4.jpg: 640x480 1 multiple, 1 subjective, 1 q_mark, 1 s_period, 27.8ms
# Speed: 2.5ms preprocess, 27.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (4)-5.jpg: 640x480 2 multiples, 2 multiple_croppeds, 3 q_marks, 27.8ms
# Speed: 2.5ms preprocess, 27.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# 0: 256x640 1 back_2, 18.2ms
# Speed: 1.2ms preprocess, 18.2ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 640)
# ####
#
#
# ####
# 0: 192x640 1 front_2, 16.9ms
# Speed: 1.0ms preprocess, 16.9ms inference, 1.2ms postprocess per image at shape (1, 3, 192, 640)
# <PIL.Image.Image image mode=RGB size=529x337>
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (4)-6.jpg: 640x480 1 subjective, 1 s_period, 27.9ms
# Speed: 2.8ms preprocess, 27.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# ####
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (4)-7.jpg: 640x480 1 multiple_cropped, 1 q_mark, 27.8ms
# Speed: 2.5ms preprocess, 27.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# 0: 320x640 1 front_4, 1 front_5, 22.9ms
# Speed: 1.4ms preprocess, 22.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
# front_5
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (4)-8.jpg: 640x480 2 multiples, 1 subjective, 2 q_marks, 27.9ms
# Speed: 2.4ms preprocess, 27.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (4)-9.jpg: 640x480 3 multiples, 1 multiple_cropped, 3 q_marks, 27.9ms
# Speed: 2.5ms preprocess, 27.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# 0: 96x640 (no detections), 13.1ms
# Speed: 0.6ms preprocess, 13.1ms inference, 0.7ms postprocess per image at shape (1, 3, 96, 640)
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (4)-10.jpg: 640x480 2 multiples, 1 multiple_cropped, 1 subjective, 3 q_marks, 1 s_period, 27.9ms
# Speed: 2.4ms preprocess, 27.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# ####
#
#
# ####
# 0: 256x640 1 front_num, 18.2ms
# Speed: 1.2ms preprocess, 18.2ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 640)
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (4)-11.jpg: 640x480 1 multiple_cropped, 27.8ms
# Speed: 2.5ms preprocess, 27.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# 0: 640x512 1 back_num, 28.5ms
# Speed: 3.0ms preprocess, 28.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (4)-12.jpg: 640x480 3 multiples, 2 multiple_croppeds, 4 q_marks, 28.1ms
# Speed: 3.6ms preprocess, 28.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
# ####
# 0: 640x448 1 back_num, 27.8ms
# Speed: 2.9ms preprocess, 27.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 448)
# ####
#
#
# ####
# 0: 256x640 1 front_num, 18.2ms
# Speed: 1.2ms preprocess, 18.2ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 640)
# <PIL.Image.Image image mode=RGB size=538x973>
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (5)-1.jpg: 640x480 1 multiple, 2 multiple_croppeds, 1 subjective, 3 q_marks, 27.8ms
# Speed: 2.4ms preprocess, 27.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# 0: 640x576 1 back_num, 35.9ms
# Speed: 2.3ms preprocess, 35.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 576)
# ####
#
#
# ####
# 0: 224x640 1 front_4, 16.7ms
# Speed: 1.0ms preprocess, 16.7ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 640)
# ####
#
#
# ####
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (5)-2.jpg: 640x480 1 multiple, 2 subjectives, 1 q_mark, 1 s_period, 26.6ms
# Speed: 2.4ms preprocess, 26.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# ####
# ####
#
#
# ####
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (5)-3.jpg: 640x480 2 multiples, 2 q_marks, 26.2ms
# Speed: 2.4ms preprocess, 26.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (5)-4.jpg: 640x480 2 multiples, 1 subjective, 2 q_marks, 1 s_period, 27.9ms
# Speed: 2.6ms preprocess, 27.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# ####
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (5)-5.jpg: 640x480 1 multiple_cropped, 1 q_mark, 27.8ms
# Speed: 2.5ms preprocess, 27.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# ####
# 0: 352x640 1 front_3, 25.1ms
# Speed: 1.6ms preprocess, 25.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (5)-6.jpg: 640x480 1 multiple, 1 multiple_cropped, 1 q_mark, 27.9ms
# Speed: 2.5ms preprocess, 27.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# ####
# 0: 256x640 1 back_3, 18.2ms
# Speed: 1.2ms preprocess, 18.2ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 640)
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (5)-7.jpg: 640x480 3 multiples, 1 multiple_cropped, 1 subjective, 4 q_marks, 27.9ms
# Speed: 3.3ms preprocess, 27.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# 0: 256x640 1 front_2, 18.2ms
# Speed: 1.2ms preprocess, 18.2ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 640)
# ####
#
#
# ####
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (5)-8.jpg: 640x480 1 multiple_cropped, 27.8ms
# Speed: 2.5ms preprocess, 27.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# 0: 256x640 1 back_2, 18.3ms
# Speed: 1.1ms preprocess, 18.3ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 640)
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (5)-9.jpg: 640x480 1 multiple, 1 q_mark, 27.8ms
# Speed: 2.4ms preprocess, 27.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (5)-10.jpg: 640x480 1 multiple, 1 multiple_cropped, 2 q_marks, 27.8ms
# Speed: 2.5ms preprocess, 27.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ####
# 0: 544x640 1 back_1, 35.4ms
# Speed: 2.9ms preprocess, 35.4ms inference, 3.7ms postprocess per image at shape (1, 3, 544, 640)
# ####
# image 1/1 /content/drive/MyDrive/MomentCapture/Colab/dataset/test/naeshin_test/2019_high_language (5)-11.jpg: 640x480 3 multiples, 1 subjective, 3 q_marks, 1 s_period, 28.3ms
# Speed: 3.0ms preprocess, 28.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# ####
# ####
#
#
# 끝

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics/
# Out:
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics

# %%
from ultralytics import YOLO

model = YOLO('./runs/detect/categorize_train5_epoch50/weights/best.pt')  # load a custom model

results = model(source='../dataset/categorize/all/data', name='categorize_detect_train1_epoch50', save_crop=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (1)-1.jpg: 640x480 3 multiples, 2 multiple_croppeds, 4 q_marks, 132.0ms
# image 2/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (1)-2.jpg: 640x480 3 multiples, 2 multiple_croppeds, 1 subjective, 4 q_marks, 1 s_period, 28.2ms
# image 3/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (1)-3.jpg: 640x480 (no detections), 28.2ms
# image 4/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (1)-4.jpg: 640x480 4 multiples, 3 multiple_croppeds, 2 subjectives, 6 q_marks, 2 s_periods, 28.3ms
# image 5/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (1)-5.jpg: 640x480 2 multiples, 1 multiple_cropped, 1 subjective, 2 q_marks, 1 s_period, 28.2ms
# image 6/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (1)-6.jpg: 640x480 1 multiple, 1 q_mark, 28.3ms
# image 7/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (1)-7.jpg: 640x480 3 multiples, 2 multiple_croppeds, 1 subjective, 5 q_marks, 1 s_period, 28.3ms
# image 8/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (1)-8.jpg: 640x480 2 multiples, 1 subjective, 2 q_marks, 1 s_period, 28.2ms
# image 9/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (10)-1.jpg: 640x480 2 multiples, 2 q_marks, 28.2ms
# image 10/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (10)-2.jpg: 640x480 6 multiples, 6 q_marks, 28.3ms
# image 11/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (10)-3.jpg: 640x480 3 multiples, 1 multiple_cropped, 2 subjectives, 4 q_marks, 1 s_period, 28.2ms
# image 12/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (10)-4.jpg: 640x480 2 multiples, 1 multiple_cropped, 2 subjectives, 2 q_marks, 1 s_period, 28.3ms
# image 13/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (10)-5.jpg: 640x480 2 multiples, 2 multiple_croppeds, 1 subjective, 3 q_marks, 1 s_period, 28.2ms
# image 14/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (10)-6.jpg: 640x480 1 multiple, 2 multiple_croppeds, 2 subjectives, 2 q_marks, 2 s_periods, 28.2ms
# image 15/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (11)-1.jpg: 640x480 4 multiples, 2 multiple_croppeds, 4 q_marks, 28.2ms
# image 16/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (11)-2.jpg: 640x480 1 multiple, 1 multiple_cropped, 2 subjectives, 1 q_mark, 2 s_periods, 28.2ms
# image 17/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (11)-3.jpg: 640x480 1 multiple, 1 multiple_cropped, 1 subjective, 2 q_marks, 28.2ms
# image 18/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (11)-4.jpg: 640x480 3 multiples, 3 multiple_croppeds, 4 q_marks, 28.2ms
# image 19/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (11)-5.jpg: 640x480 3 multiples, 1 subjective, 3 q_marks, 1 s_period, 28.2ms
# image 20/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (11)-6.jpg: 640x480 2 multiples, 2 subjectives, 2 q_marks, 2 s_periods, 28.2ms
# image 21/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (11)-7.jpg: 640x480 3 multiples, 2 q_marks, 28.3ms
# image 22/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (12)-1.jpg: 640x480 2 multiples, 1 subjective, 2 q_marks, 1 s_period, 28.2ms
# image 23/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (12)-2.jpg: 640x480 3 multiples, 3 q_marks, 28.3ms
# image 24/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (12)-3.jpg: 640x480 6 multiples, 1 subjective, 6 q_marks, 1 s_period, 28.2ms
# image 25/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (12)-4.jpg: 640x480 3 multiples, 3 q_marks, 28.2ms
# image 26/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (12)-5.jpg: 640x480 5 multiples, 1 subjective, 5 q_marks, 1 s_period, 28.2ms
# image 27/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (12)-6.jpg: 640x480 1 multiple, 1 subjective, 1 q_mark, 1 s_period, 28.2ms
# image 28/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (13)-1.jpg: 640x480 4 multiples, 1 multiple_cropped, 1 subjective, 4 q_marks, 28.1ms
# image 29/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (13)-2.jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 30/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (13)-3.jpg: 640x480 2 multiples, 1 subjective, 2 q_marks, 1 s_period, 28.2ms
# image 31/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (13)-4.jpg: 640x480 (no detections), 28.3ms
# image 32/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (13)-5.jpg: 640x480 6 multiples, 1 multiple_cropped, 2 subjectives, 7 q_marks, 2 s_periods, 29.8ms
# image 33/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (13)-6.jpg: 640x480 4 multiple_croppeds, 2 q_marks, 28.3ms
# image 34/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (13)-7.jpg: 640x480 3 multiples, 4 multiple_croppeds, 5 q_marks, 28.3ms
# image 35/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (13)-8.jpg: 640x480 3 multiples, 1 subjective, 3 q_marks, 1 s_period, 28.2ms
# image 36/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (13)-9.jpg: 640x480 1 multiple, 1 q_mark, 28.2ms
# image 37/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (14)-1.jpg: 640x480 2 multiples, 2 q_marks, 28.2ms
# image 38/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (14)-2.jpg: 640x480 5 multiples, 2 subjectives, 7 q_marks, 3 s_periods, 28.2ms
# image 39/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (14)-3.jpg: 640x480 3 multiples, 3 q_marks, 28.1ms
# image 40/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (14)-4.jpg: 640x480 2 subjectives, 2 s_periods, 28.2ms
# image 41/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (14)-5.jpg: 640x480 4 multiples, 1 subjective, 4 q_marks, 1 s_period, 28.2ms
# image 42/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (14)-6.jpg: 640x480 6 multiples, 2 subjectives, 5 q_marks, 2 s_periods, 28.2ms
# image 43/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (14)-7.jpg: 640x480 2 subjectives, 2 s_periods, 28.2ms
# image 44/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (15)-1.jpg: 640x480 2 multiples, 2 q_marks, 28.2ms
# image 45/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (15)-2.jpg: 640x480 2 multiples, 1 subjective, 1 subjective_cropped, 3 q_marks, 2 s_periods, 28.3ms
# image 46/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (15)-3.jpg: 640x480 3 multiples, 3 q_marks, 28.2ms
# image 47/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (15)-4.jpg: 640x480 2 multiples, 1 multiple_cropped, 1 subjective, 3 q_marks, 28.2ms
# image 48/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (15)-5.jpg: 640x480 4 multiples, 2 multiple_croppeds, 1 subjective, 4 q_marks, 1 s_period, 28.2ms
# image 49/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (15)-6.jpg: 640x480 2 multiples, 2 multiple_croppeds, 1 subjective, 3 q_marks, 4 s_periods, 28.2ms
# image 50/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (15)-7.jpg: 640x480 (no detections), 28.2ms
# image 51/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (15)-8.jpg: 640x480 3 multiples, 3 q_marks, 28.1ms
# image 52/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (15)-9.jpg: 640x480 4 multiples, 1 subjective, 4 q_marks, 1 s_period, 28.2ms
# image 53/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (16)-1.jpg: 640x480 1 multiple, 1 multiple_cropped, 2 q_marks, 28.2ms
# image 54/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (16)-2.jpg: 640x480 2 multiples, 3 multiple_croppeds, 1 subjective, 3 q_marks, 1 s_period, 28.2ms
# image 55/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (16)-3.jpg: 640x480 3 multiples, 4 multiple_croppeds, 5 q_marks, 28.1ms
# image 56/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (16)-4.jpg: 640x480 2 multiples, 1 multiple_cropped, 2 subjectives, 1 subjective_cropped, 2 q_marks, 2 s_periods, 28.2ms
# image 57/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (16)-5.jpg: 640x480 4 multiples, 1 multiple_cropped, 3 subjectives, 5 q_marks, 3 s_periods, 28.2ms
# image 58/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (16)-6.jpg: 640x480 1 multiple, 1 multiple_cropped, 1 subjective, 1 q_mark, 1 s_period, 28.2ms
# image 59/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (16)-7.jpg: 640x480 1 multiple, 1 subjective, 1 q_mark, 1 s_period, 28.2ms
# image 60/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (16)-8.jpg: 640x480 4 multiples, 1 subjective, 4 q_marks, 1 s_period, 28.2ms
# image 61/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (17)-1.jpg: 640x480 (no detections), 28.3ms
# image 62/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (17)-2.jpg: 640x480 6 subjectives, 5 s_periods, 28.2ms
# image 63/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (17)-3.jpg: 640x480 3 subjectives, 2 s_periods, 28.2ms
# image 64/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (17)-4.jpg: 640x480 5 subjectives, 6 s_periods, 28.2ms
# image 65/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (17)-5.jpg: 640x480 4 subjectives, 5 s_periods, 28.2ms
# image 66/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (17)-6.jpg: 640x480 1 subjective, 1 subjective_cropped, 5 s_periods, 28.3ms
# image 67/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (18)-1.jpg: 640x480 1 multiple_cropped, 1 q_mark, 28.2ms
# image 68/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (18)-2.jpg: 640x480 4 multiples, 2 multiple_croppeds, 1 subjective, 5 q_marks, 1 s_period, 28.2ms
# image 69/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (18)-3.jpg: 640x480 3 multiples, 3 multiple_croppeds, 1 subjective, 4 q_marks, 28.2ms
# image 70/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (18)-4.jpg: 640x480 3 multiples, 1 multiple_cropped, 4 q_marks, 28.2ms
# image 71/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (18)-5.jpg: 640x480 4 multiples, 3 multiple_croppeds, 4 q_marks, 28.2ms
# image 72/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (18)-6.jpg: 640x480 1 multiple, 2 multiple_croppeds, 3 q_marks, 28.2ms
# image 73/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (18)-7.jpg: 640x480 (no detections), 28.2ms
# image 74/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (18)-8.jpg: 640x480 3 multiples, 1 multiple_cropped, 4 q_marks, 28.2ms
# image 75/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (18)-9.jpg: 640x480 3 multiples, 1 multiple_cropped, 3 q_marks, 28.3ms
# image 76/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (19)-1.jpg: 640x480 3 multiples, 1 multiple_cropped, 1 subjective, 3 q_marks, 1 s_period, 31.9ms
# image 77/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (19)-2.jpg: 640x480 2 multiples, 2 multiple_croppeds, 3 q_marks, 28.3ms
# image 78/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (19)-3.jpg: 640x480 4 multiples, 1 multiple_cropped, 3 subjectives, 5 q_marks, 4 s_periods, 28.3ms
# image 79/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (19)-4.jpg: 640x480 1 multiple, 1 multiple_cropped, 1 subjective, 1 q_mark, 1 s_period, 28.3ms
# image 80/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (19)-5.jpg: 640x480 2 multiples, 2 multiple_croppeds, 3 q_marks, 28.2ms
# image 81/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (19)-6.jpg: 640x480 4 multiples, 1 multiple_cropped, 1 subjective_cropped, 5 q_marks, 28.2ms
# image 82/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (19)-7.jpg: 640x480 1 multiple_cropped, 1 subjective, 1 s_period, 28.2ms
# image 83/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (2)-1.jpg: 640x480 2 multiples, 2 q_marks, 28.2ms
# image 84/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (2)-10.jpg: 640x480 1 multiple_cropped, 28.3ms
# image 85/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (2)-2.jpg: 640x480 2 multiples, 1 multiple_cropped, 3 q_marks, 28.3ms
# image 86/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (2)-3.jpg: 640x480 5 multiples, 1 multiple_cropped, 4 q_marks, 28.3ms
# image 87/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (2)-4.jpg: 640x480 4 multiples, 4 q_marks, 28.2ms
# image 88/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (2)-5.jpg: 640x480 4 multiples, 1 multiple_cropped, 4 q_marks, 28.2ms
# image 89/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (2)-6.jpg: 640x480 5 multiples, 1 multiple_cropped, 6 q_marks, 28.3ms
# image 90/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (2)-7.jpg: 640x480 3 multiples, 3 multiple_croppeds, 4 q_marks, 208.8ms
# image 91/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (2)-8.jpg: 640x480 3 multiples, 2 multiple_croppeds, 3 q_marks, 28.2ms
# image 92/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (2)-9.jpg: 640x480 2 multiples, 1 multiple_cropped, 3 q_marks, 28.3ms
# image 93/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (20)-1.jpg: 640x480 1 multiple_cropped, 1 q_mark, 28.2ms
# image 94/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (20)-10.jpg: 640x480 1 multiple, 1 multiple_cropped, 1 subjective, 1 q_mark, 1 s_period, 28.2ms
# image 95/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (20)-2.jpg: 640x480 4 multiples, 4 multiple_croppeds, 2 subjectives, 6 q_marks, 1 s_period, 28.2ms
# image 96/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (20)-3.jpg: 640x480 3 multiples, 2 multiple_croppeds, 1 subjective, 3 q_marks, 1 s_period, 28.2ms
# image 97/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (20)-4.jpg: 640x480 2 multiples, 3 multiple_croppeds, 3 q_marks, 28.2ms
# image 98/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (20)-5.jpg: 640x480 4 multiples, 3 multiple_croppeds, 6 q_marks, 28.2ms
# image 99/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (20)-6.jpg: 640x480 1 multiple, 1 multiple_cropped, 1 subjective, 1 q_mark, 1 s_period, 28.2ms
# image 100/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (20)-7.jpg: 640x480 1 q_mark, 28.2ms
# image 101/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (20)-8.jpg: 640x480 (no detections), 28.2ms
# image 102/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (20)-9.jpg: 640x480 4 multiples, 1 multiple_cropped, 5 q_marks, 1 s_period, 28.2ms
# image 103/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (21)-1.jpg: 640x480 3 multiples, 2 multiple_croppeds, 1 subjective, 4 q_marks, 1 s_period, 28.2ms
# image 104/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (21)-2.jpg: 640x480 5 multiples, 2 subjectives, 5 q_marks, 2 s_periods, 28.2ms
# image 105/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (21)-3.jpg: 640x480 3 multiples, 2 subjectives, 3 q_marks, 2 s_periods, 28.2ms
# image 106/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (21)-4.jpg: 640x480 (no detections), 28.2ms
# image 107/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (21)-5.jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 108/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (21)-6.jpg: 640x480 2 subjectives, 2 s_periods, 28.2ms
# image 109/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (21)-7.jpg: 640x480 3 multiples, 1 subjective, 3 q_marks, 1 s_period, 28.2ms
# image 110/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (22)-1.jpg: 640x480 1 multiple, 1 multiple_cropped, 3 q_marks, 28.2ms
# image 111/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (22)-2.jpg: 640x480 5 multiples, 1 multiple_cropped, 4 q_marks, 28.3ms
# image 112/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (22)-3.jpg: 640x480 3 multiples, 2 subjectives, 4 q_marks, 2 s_periods, 28.2ms
# image 113/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (22)-4.jpg: 640x480 3 multiples, 1 multiple_cropped, 2 subjectives, 4 q_marks, 3 s_periods, 28.5ms
# image 114/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (22)-5.jpg: 640x480 2 multiples, 3 multiple_croppeds, 3 q_marks, 28.2ms
# image 115/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (22)-6.jpg: 640x480 3 multiples, 3 q_marks, 28.2ms
# image 116/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (23)-1.jpg: 640x480 4 multiples, 2 subjectives, 4 q_marks, 3 s_periods, 28.2ms
# image 117/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (23)-2.jpg: 640x480 4 multiples, 1 multiple_cropped, 6 q_marks, 28.2ms
# image 118/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (23)-3.jpg: 640x480 3 multiples, 1 multiple_cropped, 2 subjectives, 3 q_marks, 1 s_period, 28.2ms
# image 119/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (23)-4.jpg: 640x480 (no detections), 28.2ms
# image 120/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (23)-5.jpg: 640x480 4 multiples, 4 q_marks, 28.2ms
# image 121/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (23)-6.jpg: 640x480 1 multiple, 1 multiple_cropped, 2 q_marks, 28.2ms
# image 122/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (23)-7.jpg: 640x480 4 multiples, 1 subjective, 4 q_marks, 1 s_period, 28.1ms
# image 123/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (23)-8.jpg: 640x480 2 multiples, 2 multiple_croppeds, 1 subjective, 3 q_marks, 28.3ms
# image 124/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (23)-9.jpg: 640x480 2 multiples, 2 multiple_croppeds, 1 subjective, 2 q_marks, 1 s_period, 28.2ms
# image 125/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (24)-1.jpg: 640x480 5 multiples, 5 q_marks, 28.1ms
# image 126/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (24)-2.jpg: 640x480 3 multiples, 3 q_marks, 28.2ms
# image 127/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (24)-3.jpg: 640x480 3 multiples, 1 subjective, 3 q_marks, 1 s_period, 28.2ms
# image 128/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (24)-4.jpg: 640x480 1 multiple_cropped, 1 subjective, 1 q_mark, 1 s_period, 28.2ms
# image 129/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (24)-5.jpg: 640x480 1 multiple, 3 multiple_croppeds, 1 subjective, 3 q_marks, 28.2ms
# image 130/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (24)-6.jpg: 640x480 (no detections), 28.2ms
# image 131/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (24)-7.jpg: 640x480 3 multiples, 2 multiple_croppeds, 4 q_marks, 28.2ms
# image 132/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (24)-8.jpg: 640x480 4 multiples, 2 subjectives, 4 q_marks, 2 s_periods, 28.2ms
# image 133/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (25)-1.jpg: 640x480 4 multiples, 2 subjectives, 4 q_marks, 2 s_periods, 28.2ms
# image 134/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (25)-2.jpg: 640x480 3 multiples, 1 subjective, 3 q_marks, 1 s_period, 28.2ms
# image 135/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (25)-3.jpg: 640x480 2 multiples, 2 multiple_croppeds, 2 subjectives, 3 q_marks, 2 s_periods, 28.2ms
# image 136/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (25)-4.jpg: 640x480 4 multiples, 4 q_marks, 28.3ms
# image 137/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (25)-5.jpg: 640x480 1 multiple, 1 q_mark, 28.2ms
# image 138/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (25)-6.jpg: 640x480 1 multiple_cropped, 1 q_mark, 28.3ms
# image 139/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (25)-7.jpg: 640x480 4 multiples, 3 multiple_croppeds, 5 q_marks, 28.2ms
# image 140/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (25)-8.jpg: 640x480 1 multiple, 1 subjective, 1 q_mark, 1 s_period, 39.0ms
# image 141/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (26)-1.jpg: 640x480 3 multiples, 3 multiple_croppeds, 5 q_marks, 29.0ms
# image 142/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (26)-2.jpg: 640x480 2 multiples, 4 multiple_croppeds, 4 q_marks, 28.3ms
# image 143/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (26)-3.jpg: 640x480 1 multiple, 1 multiple_cropped, 1 subjective, 2 subjective_croppeds, 1 q_mark, 1 s_period, 28.2ms
# image 144/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (26)-4.jpg: 640x480 6 multiples, 1 subjective, 6 q_marks, 1 s_period, 28.9ms
# image 145/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (26)-5.jpg: 640x480 4 multiples, 1 subjective, 4 q_marks, 1 s_period, 28.2ms
# image 146/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (27)-1.jpg: 640x480 (no detections), 28.3ms
# image 147/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (27)-2.jpg: 640x480 4 multiples, 3 multiple_croppeds, 5 q_marks, 28.3ms
# image 148/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (27)-3.jpg: 640x480 7 multiples, 7 q_marks, 28.1ms
# image 149/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (27)-4.jpg: 640x480 4 multiples, 4 q_marks, 28.2ms
# image 150/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (27)-5.jpg: 640x480 3 multiples, 2 multiple_croppeds, 4 q_marks, 28.3ms
# image 151/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (27)-6.jpg: 640x480 2 multiples, 2 q_marks, 28.2ms
# image 152/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (27)-7.jpg: 640x480 6 multiples, 6 q_marks, 28.2ms
# image 153/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (27)-8.jpg: 640x480 1 multiple, 1 q_mark, 28.2ms
# image 154/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (27)-9.jpg: 640x480 2 multiples, 2 q_marks, 28.2ms
# image 155/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (28)-1.jpg: 640x480 4 multiples, 1 subjective, 4 q_marks, 1 s_period, 28.2ms
# image 156/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (28)-2.jpg: 640x480 3 multiples, 3 q_marks, 28.2ms
# image 157/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (28)-3.jpg: 640x480 2 multiples, 1 subjective, 2 q_marks, 1 s_period, 28.2ms
# image 158/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (28)-4.jpg: 640x480 4 multiples, 4 q_marks, 28.2ms
# image 159/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (28)-5.jpg: 640x480 5 multiples, 5 q_marks, 1 s_period, 28.2ms
# image 160/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (28)-6.jpg: 640x480 3 multiples, 1 subjective, 3 q_marks, 2 s_periods, 28.2ms
# image 161/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (28)-7.jpg: 640x480 2 multiples, 2 multiple_croppeds, 3 q_marks, 28.3ms
# image 162/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (28)-8.jpg: 640x480 2 multiples, 2 q_marks, 28.2ms
# image 163/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (29)-1.jpg: 640x480 1 multiple, 2 multiple_croppeds, 2 q_marks, 28.2ms
# image 164/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (29)-2.jpg: 640x480 1 multiple, 1 multiple_cropped, 2 q_marks, 28.2ms
# image 165/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (29)-3.jpg: 640x480 1 multiple, 1 multiple_cropped, 1 q_mark, 28.2ms
# image 166/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (29)-4.jpg: 640x480 1 multiple, 3 multiple_croppeds, 1 subjective_cropped, 2 q_marks, 28.3ms
# image 167/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (29)-5.jpg: 640x480 4 multiples, 4 q_marks, 28.2ms
# image 168/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (29)-6.jpg: 640x480 4 multiples, 3 multiple_croppeds, 6 q_marks, 28.2ms
# image 169/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (29)-7.jpg: 640x480 4 multiples, 1 multiple_cropped, 4 q_marks, 28.2ms
# image 170/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (29)-8.jpg: 640x480 3 multiples, 2 multiple_croppeds, 4 q_marks, 28.2ms
# image 171/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (29)-9.jpg: 640x480 2 multiples, 2 q_marks, 28.2ms
# image 172/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (3)-1.jpg: 640x480 1 multiple_cropped, 1 q_mark, 28.2ms
# image 173/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (3)-2.jpg: 640x480 5 multiples, 3 multiple_croppeds, 6 q_marks, 28.3ms
# image 174/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (3)-3.jpg: 640x480 5 multiples, 1 multiple_cropped, 1 subjective, 6 q_marks, 1 s_period, 28.3ms
# image 175/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (3)-4.jpg: 640x480 4 multiples, 3 multiple_croppeds, 5 q_marks, 28.2ms
# image 176/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (3)-5.jpg: 640x480 1 multiple, 3 multiple_croppeds, 1 subjective, 2 q_marks, 1 s_period, 28.2ms
# image 177/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (30)-1.jpg: 640x480 3 multiples, 1 subjective_cropped, 3 q_marks, 1 s_period, 28.2ms
# image 178/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (30)-2.jpg: 640x480 4 multiples, 1 subjective, 3 subjective_croppeds, 4 q_marks, 1 s_period, 28.4ms
# image 179/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (30)-3.jpg: 640x480 5 multiples, 1 subjective, 5 q_marks, 1 s_period, 28.2ms
# image 180/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (30)-4.jpg: 640x480 2 multiples, 2 subjectives, 1 subjective_cropped, 2 q_marks, 2 s_periods, 28.3ms
# image 181/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (30)-5.jpg: 640x480 3 multiples, 3 multiple_croppeds, 5 q_marks, 28.2ms
# image 182/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (30)-6.jpg: 640x480 1 multiple, 1 multiple_cropped, 1 subjective, 1 q_mark, 1 s_period, 28.2ms
# image 183/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (31)-1.jpg: 640x480 (no detections), 28.2ms
# image 184/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (31)-10.jpg: 640x480 3 multiples, 3 multiple_croppeds, 5 q_marks, 28.2ms
# image 185/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (31)-11.jpg: 640x480 1 multiple, 1 multiple_cropped, 1 q_mark, 28.2ms
# image 186/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (31)-2.jpg: 640x480 2 multiples, 1 multiple_cropped, 3 q_marks, 28.2ms
# image 187/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (31)-3.jpg: 640x480 5 multiples, 3 multiple_croppeds, 6 q_marks, 28.2ms
# image 188/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (31)-4.jpg: 640x480 (no detections), 28.2ms
# image 189/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (31)-5.jpg: 640x480 5 multiples, 2 multiple_croppeds, 6 q_marks, 28.2ms
# image 190/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (31)-6.jpg: 640x480 1 multiple, 1 multiple_cropped, 1 q_mark, 28.2ms
# image 191/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (31)-7.jpg: 640x480 3 multiples, 3 multiple_croppeds, 5 q_marks, 28.2ms
# image 192/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (31)-8.jpg: 640x480 2 multiples, 3 multiple_croppeds, 3 q_marks, 28.2ms
# image 193/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (31)-9.jpg: 640x480 2 multiples, 2 q_marks, 28.2ms
# image 194/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (32)-1.jpg: 640x480 7 multiples, 7 q_marks, 28.2ms
# image 195/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (32)-2.jpg: 640x480 8 multiples, 8 q_marks, 28.2ms
# image 196/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (32)-3.jpg: 640x480 2 multiples, 1 multiple_cropped, 3 q_marks, 28.2ms
# image 197/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (32)-4.jpg: 640x480 7 multiples, 1 multiple_cropped, 7 q_marks, 28.2ms
# image 198/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (32)-5.jpg: 640x480 3 multiples, 1 multiple_cropped, 4 q_marks, 28.2ms
# image 199/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (32)-6.jpg: 640x480 2 multiples, 1 multiple_cropped, 3 q_marks, 28.3ms
# image 200/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (32)-7.jpg: 640x480 1 multiple, 1 q_mark, 28.2ms
# image 201/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (33)-1.jpg: 640x480 3 multiple_croppeds, 1 subjective, 3 q_marks, 1 s_period, 28.2ms
# image 202/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (33)-2.jpg: 640x480 6 multiples, 1 subjective, 6 q_marks, 28.2ms
# image 203/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (33)-3.jpg: 640x480 1 multiple, 1 subjective, 1 s_period, 28.3ms
# image 204/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (33)-4.jpg: 640x480 3 multiples, 2 multiple_croppeds, 4 q_marks, 28.3ms
# image 205/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (33)-5.jpg: 640x480 1 multiple, 1 subjective, 1 q_mark, 1 s_period, 28.3ms
# image 206/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (33)-6.jpg: 640x480 2 multiples, 3 subjectives, 1 subjective_cropped, 2 q_marks, 1 s_period, 28.2ms
# image 207/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (34)-1.jpg: 640x480 (no detections), 28.2ms
# image 208/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (34)-2.jpg: 640x480 4 multiples, 3 multiple_croppeds, 6 q_marks, 28.2ms
# image 209/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (34)-3.jpg: 640x480 1 multiple, 2 multiple_croppeds, 2 q_marks, 28.1ms
# image 210/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (34)-4.jpg: 640x480 1 multiple_cropped, 28.1ms
# image 211/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (34)-5.jpg: 640x480 5 multiples, 5 q_marks, 1 s_period, 28.2ms
# image 212/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (34)-6.jpg: 640x480 4 multiples, 1 subjective, 5 q_marks, 28.2ms
# image 213/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (34)-7.jpg: 640x480 2 multiples, 1 multiple_cropped, 3 q_marks, 28.2ms
# image 214/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (34)-8.jpg: 640x480 3 multiples, 3 multiple_croppeds, 4 q_marks, 28.2ms
# image 215/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (35)-1.jpg: 640x480 3 multiples, 3 q_marks, 28.2ms
# image 216/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (35)-2.jpg: 640x480 4 multiples, 4 q_marks, 28.2ms
# image 217/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (35)-3.jpg: 640x480 5 multiples, 1 subjective, 2 subjective_croppeds, 5 q_marks, 1 s_period, 28.2ms
# image 218/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (35)-4.jpg: 640x480 2 multiples, 1 multiple_cropped, 3 q_marks, 28.2ms
# image 219/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (35)-5.jpg: 640x480 4 multiples, 2 multiple_croppeds, 5 q_marks, 28.2ms
# image 220/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (35)-6.jpg: 640x480 1 multiple_cropped, 1 subjective, 1 s_period, 28.2ms
# image 221/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (36)-1.jpg: 640x480 3 multiples, 3 q_marks, 28.2ms
# image 222/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (36)-2.jpg: 640x480 1 multiple, 1 multiple_cropped, 2 q_marks, 28.2ms
# image 223/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (36)-3.jpg: 640x480 2 multiples, 3 multiple_croppeds, 3 q_marks, 28.2ms
# image 224/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (36)-4.jpg: 640x480 2 multiples, 2 q_marks, 28.2ms
# image 225/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (36)-5.jpg: 640x480 4 multiples, 1 multiple_cropped, 5 q_marks, 28.2ms
# image 226/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (36)-6.jpg: 640x480 2 multiples, 4 multiple_croppeds, 4 q_marks, 28.2ms
# image 227/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (36)-7.jpg: 640x480 2 multiples, 1 multiple_cropped, 1 subjective, 2 q_marks, 1 s_period, 28.2ms
# image 228/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (36)-8.jpg: 640x480 4 multiples, 2 multiple_croppeds, 5 q_marks, 28.2ms
# image 229/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (36)-9.jpg: 640x480 2 multiples, 1 multiple_cropped, 2 q_marks, 28.2ms
# image 230/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (37)-1.jpg: 640x480 1 subjective, 1 s_period, 28.2ms
# image 231/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (37)-2.jpg: 640x480 4 subjectives, 4 s_periods, 28.2ms
# image 232/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (37)-3.jpg: 640x480 2 subjectives, 1 subjective_cropped, 5 s_periods, 28.2ms
# image 233/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (37)-4.jpg: 640x480 2 subjectives, 1 subjective_cropped, 2 s_periods, 28.2ms
# image 234/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (38)-1.jpg: 640x480 3 multiples, 3 multiple_croppeds, 4 q_marks, 28.2ms
# image 235/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (38)-2.jpg: 640x480 3 multiples, 1 subjective, 3 q_marks, 1 s_period, 28.2ms
# image 236/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (38)-3.jpg: 640x480 1 multiple, 1 subjective, 1 q_mark, 1 s_period, 28.2ms
# image 237/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (38)-4.jpg: 640x480 4 multiples, 1 multiple_cropped, 2 subjectives, 5 q_marks, 3 s_periods, 28.2ms
# image 238/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (38)-5.jpg: 640x480 4 multiples, 2 multiple_croppeds, 1 subjective, 6 q_marks, 2 s_periods, 28.2ms
# image 239/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (38)-6.jpg: 640x480 3 multiples, 1 multiple_cropped, 2 subjectives, 1 subjective_cropped, 3 q_marks, 3 s_periods, 28.2ms
# image 240/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (38)-7.jpg: 640x480 1 subjective_cropped, 28.2ms
# image 241/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (39)-1.jpg: 640x480 3 multiples, 3 q_marks, 28.2ms
# image 242/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (39)-2.jpg: 640x480 2 multiples, 2 multiple_croppeds, 1 subjective, 3 q_marks, 1 s_period, 28.2ms
# image 243/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (39)-3.jpg: 640x480 3 multiples, 3 multiple_croppeds, 3 q_marks, 28.2ms
# image 244/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (39)-4.jpg: 640x480 1 multiple, 3 multiple_croppeds, 1 subjective, 2 q_marks, 1 s_period, 28.2ms
# image 245/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (39)-5.jpg: 640x480 3 multiples, 2 multiple_croppeds, 2 subjectives, 4 q_marks, 4 s_periods, 28.2ms
# image 246/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (39)-6.jpg: 640x480 2 multiples, 2 q_marks, 28.2ms
# image 247/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (39)-7.jpg: 640x480 4 multiples, 1 subjective, 4 q_marks, 2 s_periods, 28.2ms
# image 248/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (4)-1.jpg: 640x480 (no detections), 28.2ms
# image 249/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (4)-2.jpg: 640x480 3 multiples, 2 multiple_croppeds, 1 subjective, 4 q_marks, 1 s_period, 28.2ms
# ...
# image 1173/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (137).jpg: 640x480 6 multiples, 7 q_marks, 28.3ms
# image 1174/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (138).jpg: 640x480 10 multiples, 10 q_marks, 28.2ms
# image 1175/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (139).jpg: 640x480 8 multiples, 8 q_marks, 28.2ms
# image 1176/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (14).jpg: 640x480 6 multiples, 7 q_marks, 28.2ms
# image 1177/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (140).jpg: 640x480 7 multiples, 7 q_marks, 28.2ms
# image 1178/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (141).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1179/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (142).jpg: 640x480 6 multiples, 8 q_marks, 28.2ms
# image 1180/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (143).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1181/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (144).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1182/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (145).jpg: 640x480 4 multiples, 4 q_marks, 28.2ms
# image 1183/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (146).jpg: 640x480 4 multiples, 4 q_marks, 28.2ms
# image 1184/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (147).jpg: 640x480 6 multiples, 5 q_marks, 28.2ms
# image 1185/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (148).jpg: 640x480 5 multiples, 5 q_marks, 28.1ms
# image 1186/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (149).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1187/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (15).jpg: 640x480 6 multiples, 6 q_marks, 28.2ms
# image 1188/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (150).jpg: 640x480 4 multiples, 4 q_marks, 28.2ms
# image 1189/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (151).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1190/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (152).jpg: 640x480 6 multiples, 6 q_marks, 28.2ms
# image 1191/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (153).jpg: 640x480 5 multiples, 6 q_marks, 28.1ms
# image 1192/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (154).jpg: 640x480 5 multiples, 6 q_marks, 28.1ms
# image 1193/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (155).jpg: 640x480 5 multiples, 6 q_marks, 28.2ms
# image 1194/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (156).jpg: 640x480 6 multiples, 7 q_marks, 28.2ms
# image 1195/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (157).jpg: 640x480 4 multiples, 5 q_marks, 28.2ms
# image 1196/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (158).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1197/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (159).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1198/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (16).jpg: 640x480 4 multiples, 5 q_marks, 28.2ms
# image 1199/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (160).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1200/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (161).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1201/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (162).jpg: 640x480 9 multiples, 10 q_marks, 28.2ms
# image 1202/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (163).jpg: 640x480 7 multiples, 8 q_marks, 28.2ms
# image 1203/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (164).jpg: 640x480 7 multiples, 7 q_marks, 28.3ms
# image 1204/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (165).jpg: 640x480 7 multiples, 7 q_marks, 28.3ms
# image 1205/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (166).jpg: 640x480 5 multiples, 6 q_marks, 28.3ms
# image 1206/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (167).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1207/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (168).jpg: 640x480 5 multiples, 6 q_marks, 28.2ms
# image 1208/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (169).jpg: 640x480 5 multiples, 5 q_marks, 28.3ms
# image 1209/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (17).jpg: 640x480 4 multiples, 5 q_marks, 28.3ms
# image 1210/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (170).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1211/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (171).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1212/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (172).jpg: 640x480 5 multiples, 6 q_marks, 28.2ms
# image 1213/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (173).jpg: 640x480 5 multiples, 4 q_marks, 28.2ms
# image 1214/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (174).jpg: 640x480 8 multiples, 8 q_marks, 28.2ms
# image 1215/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (175).jpg: 640x480 7 multiples, 7 q_marks, 28.2ms
# image 1216/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (176).jpg: 640x480 6 multiples, 6 q_marks, 28.2ms
# image 1217/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (177).jpg: 640x480 9 multiples, 9 q_marks, 28.2ms
# image 1218/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (178).jpg: 640x480 6 multiples, 7 q_marks, 28.2ms
# image 1219/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (179).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1220/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (18).jpg: 640x480 4 multiples, 4 q_marks, 28.2ms
# image 1221/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (180).jpg: 640x480 6 multiples, 8 q_marks, 28.2ms
# image 1222/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (181).jpg: 640x480 3 multiples, 3 q_marks, 28.2ms
# image 1223/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (182).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1224/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (183).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1225/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (184).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1226/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (185).jpg: 640x480 5 multiples, 5 q_marks, 28.4ms
# image 1227/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (186).jpg: 640x480 8 multiples, 8 q_marks, 28.2ms
# image 1228/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (187).jpg: 640x480 7 multiples, 7 q_marks, 28.2ms
# image 1229/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (188).jpg: 640x480 7 multiples, 7 q_marks, 28.2ms
# image 1230/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (189).jpg: 640x480 4 multiples, 2 q_marks, 28.2ms
# image 1231/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (19).jpg: 640x480 6 multiples, 6 q_marks, 28.2ms
# image 1232/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (190).jpg: 640x480 12 multiples, 1 q_mark, 12 q_periods, 28.2ms
# image 1233/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (191).jpg: 640x480 8 multiples, 5 q_marks, 3 q_periods, 28.2ms
# image 1234/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (192).jpg: 640x480 4 multiples, 4 q_marks, 28.2ms
# image 1235/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (193).jpg: 640x480 4 multiples, 4 q_marks, 28.2ms
# image 1236/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (194).jpg: 640x480 4 multiples, 1 q_mark, 28.2ms
# image 1237/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (195).jpg: 640x480 4 multiples, 1 q_mark, 28.1ms
# image 1238/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (196).jpg: 640x480 5 multiples, 5 q_marks, 28.1ms
# image 1239/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (2).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1240/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (20).jpg: 640x480 6 multiples, 6 q_marks, 30.6ms
# image 1241/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (21).jpg: 640x480 4 multiples, 4 q_marks, 28.2ms
# image 1242/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (22).jpg: 640x480 4 multiples, 4 q_marks, 28.9ms
# image 1243/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (23).jpg: 640x480 6 multiples, 6 q_marks, 28.2ms
# image 1244/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (24).jpg: 640x480 5 multiples, 6 q_marks, 28.2ms
# image 1245/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (25).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1246/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (26).jpg: 640x480 8 multiples, 8 q_marks, 28.3ms
# image 1247/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (27).jpg: 640x480 8 multiples, 9 q_marks, 28.3ms
# image 1248/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (28).jpg: 640x480 7 multiples, 7 q_marks, 28.2ms
# image 1249/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (29).jpg: 640x480 7 multiples, 7 q_marks, 28.1ms
# image 1250/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (3).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1251/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (30).jpg: 640x480 6 multiples, 6 q_marks, 28.2ms
# image 1252/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (31).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1253/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (32).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1254/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (33).jpg: 640x480 4 multiples, 5 q_marks, 28.2ms
# image 1255/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (34).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1256/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (35).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1257/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (36).jpg: 640x480 5 multiples, 5 q_marks, 28.1ms
# image 1258/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (37).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1259/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (38).jpg: 640x480 5 multiples, 5 q_marks, 28.3ms
# image 1260/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (39).jpg: 640x480 5 multiples, 5 q_marks, 28.2ms
# image 1261/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (4).jpg: 640x480 5 multiples, 5 q_marks, 3177.4ms
# image 1262/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (40).jpg: 640x480 5 multiples, 5 q_marks, 28921.1ms
# image 1263/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (41).jpg: 640x480 5 multiples, 5 q_marks, 39413.5ms
# WARNING ⚠️ NMS time limit 2.050s exceeded
# image 1264/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (42).jpg: 640x480 4 multiples, 4 q_marks, 58839.2ms
# WARNING ⚠️ NMS time limit 2.050s exceeded
# image 1265/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (43).jpg: 640x480 5 multiples, 5 q_marks, 68710.3ms
# WARNING ⚠️ NMS time limit 2.050s exceeded
# image 1266/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (44).jpg: 640x480 6 multiples, 6 q_marks, 84285.7ms
# WARNING ⚠️ NMS time limit 2.050s exceeded
# image 1267/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2021_suneung (45).jpg: 640x480 5 multiples, 6 q_marks, 168804.8ms

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics/
# Out:
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics

# %%
from ultralytics import YOLO

model = YOLO('./runs/detect/matching_train1_epoch50/weights/best.pt')

results = model(source='./runs/detect/categorize_detect_train1_epoch50/crops/multiple_cropped', name='matching_detect_train1_epoch50', show=True, save=True, save_crop=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()

# %% [markdown]
# # **end**
