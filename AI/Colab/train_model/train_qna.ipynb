# %% [markdown]
# # **drive mount**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -U ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.4/709.4 kB 9.5 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics/
# !pip install -U ultralytics

from ultralytics import YOLO
# Out:
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.4/709.4 kB 6.9 MB/s eta 0:00:00
# ...

# %%
# !pip install -U ultralytics

# %% [markdown]
# # **requirements**

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-a03419c27f5b> in <cell line: 2>()
#       1 get_ipython().run_line_magic('pip', 'install ultralytics')
# ----> 2 import ultralytics
#       3 ultralytics.checks()
#
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics/ultralytics/__init__.py in <module>
#       3 __version__ = '8.0.200'
#       4
# ----> 5 from ultralytics.models import RTDETR, SAM, YOLO
#       6 from ultralytics.models.fastsam import FastSAM
#       7 from ultralytics.models.nas import NAS
#
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics/ultralytics/models/__init__.py in <module>
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       2
# ----> 3 from .rtdetr import RTDETR
#       4 from .sam import SAM
#       5 from .yolo import YOLO
#
# ...

# %%
# %cd /content/drive/MyDrive/순간포착/Colab
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 16974, done.
# remote: Counting objects: 100% (688/688), done.
# remote: Compressing objects: 100% (528/528), done.
# remote: Total 16974 (delta 361), reused 277 (delta 159), pack-reused 16286
# Receiving objects: 100% (16974/16974), 9.29 MiB | 10.94 MiB/s, done.
# Resolving deltas: 100% (11662/11662), done.
# Updating files: 100% (450/450), done.

# %% [markdown]
# # **train**

# %% [markdown]
# ##**처음 train**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics
# Out:
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics

# %%
from ultralytics.data.utils import autosplit

autosplit(path='../dataset/categorize/suneung/data')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-1d333f9bf920> in <cell line: 1>()
# ----> 1 from ultralytics.data.utils import autosplit
#       2
#       3 autosplit(path='../dataset/categorize/categorize_all/data')
#
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics/ultralytics/__init__.py in <module>
#       3 __version__ = '8.0.200'
#       4
# ----> 5 from ultralytics.models import RTDETR, SAM, YOLO
#       6 from ultralytics.models.fastsam import FastSAM
#       7 from ultralytics.models.nas import NAS
#
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics/ultralytics/models/__init__.py in <module>
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       2
# ----> 3 from .rtdetr import RTDETR
#       4 from .sam import SAM
#       5 from .yolo import YOLO
#
# ...

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics
# Out:
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics
# !pip install -U ultralytics

from ultralytics import YOLO
# Out:
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.4/709.4 kB 9.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')
results = model.train(
    data='../dataset/categorize/suneung/data.yaml',
    batch=20,
    epochs=50,
    name='categorize_train1_epoch50')
# Out:
# Ultralytics YOLOv8.1.8 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### **(best) train5 epoch50**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics
# Out:
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics

# %%
pip install -U ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.5/719.5 kB 6.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics.data.utils import autosplit

autosplit(path='../dataset/categorize/all/data')
# Out:
# Autosplitting images from ../dataset/categorize/all/data
# 100%|██████████| 1550/1550 [00:06<00:00, 227.39it/s]

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')
results = model.train(
    data='../dataset/categorize/all/data.yaml',
    batch=16,
    epochs=50,
    name='categorize_train5_epoch50')
# Out:
# New https://pypi.org/project/ultralytics/8.1.24 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### **train6 epoch100**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics
# Out:
# /content/drive/.shortcut-targets-by-id/1F2h4dTE5AEwzXuzoGz7DGAYLmbHrwkX9/MomentCapture/Colab/ultralytics

# %%
# !pip install -U ultralytics

# %%
from ultralytics.data.utils import autosplit

autosplit(path='../dataset/categorize/all/data')
# Out:
# Autosplitting images from ../dataset/categorize/all/data
# 100%|██████████| 1550/1550 [00:10<00:00, 144.79it/s]

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')
results = model.train(
    data='../dataset/categorize/all/data.yaml',
    batch=20,
    epochs=100,
    name='categorize_train6_epoch100')
# Out:
# New https://pypi.org/project/ultralytics/8.1.24 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### **train7 epoch50**

# %% [markdown]
# batch를 4로 줄이니 시간이 너무 오래 걸린다.
# 더 큰 batch 성능 체크를 위해 32로 늘린다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics
# Out:
# /content/drive/.shortcut-targets-by-id/1F2h4dTE5AEwzXuzoGz7DGAYLmbHrwkX9/MomentCapture/Colab/ultralytics

# %%
# !pip install -U ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.5/719.5 kB 9.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics.data.utils import autosplit

autosplit(path='../dataset/categorize/all/data', weights=(0.8, 0.2, 0.0))
# Out:
# Autosplitting images from ../dataset/categorize/all/data
# 100%|██████████| 1550/1550 [00:06<00:00, 232.14it/s]

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')
results = model.train(
    data='../dataset/categorize/all/data.yaml',
    batch=32,
    epochs=50,
    name='categorize_train7_epoch50')
# Out:
# New https://pypi.org/project/ultralytics/8.1.24 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # **validation**

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics/
# Out:
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics

# %% [markdown]
# ## **train5 epoch50**

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/categorize_epoch50_train5/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val(data='../dataset/categorize/all/data.yaml', name='categorize_val_train5_epoch50')  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25843813 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/drive/MyDrive/MomentCapture/Colab/dataset/categorize/all/data.cache... 167 images, 3 backgrounds, 0 corrupt: 100%|██████████| 167/167 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:15<00:00,  1.38s/it]
#                    all        167       1475      0.908      0.832      0.902      0.722
#               multiple        167        586      0.933      0.946      0.968      0.913
#       multiple_cropped        167        103      0.942       0.95      0.977      0.877
#             subjective        167         59      0.796      0.983      0.959      0.903
#     subjective_cropped        167         23      0.901      0.609      0.732       0.63
# ...

# %% [markdown]
# ## **train6 epoch100**

# %%
from ultralytics.data.utils import autosplit

autosplit(path='../dataset/categorize/all/data', weights=(0.7, 0.3, 0.0))
# Out:
# Autosplitting images from ../dataset/categorize/all/data
# 100%|██████████| 1550/1550 [00:06<00:00, 222.80it/s]

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/categorize_epoch100_train6/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val(data='../dataset/categorize/all/data.yaml', name='categorize_val_train6_epoch100')  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25843813 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/1F2h4dTE5AEwzXuzoGz7DGAYLmbHrwkX9/MomentCapture/Colab/dataset/categorize/all/data.cache... 466 images, 8 backgrounds, 0 corrupt: 100%|██████████| 467/467 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 30/30 [00:26<00:00,  1.11it/s]
#                    all        467       3937      0.656      0.211      0.286      0.217
#               multiple        467       1556       0.83      0.598      0.795      0.674
#       multiple_cropped        467        280      0.355    0.00357     0.0307     0.0237
#             subjective        467        165          1      0.157      0.288      0.269
#     subjective_cropped        467         57          0          0          0          0
# ...

# %% [markdown]
# ## **train7 epoch50**

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/categorize_epoch50_train7/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val(data='../dataset/categorize/all/data.yaml', name='categorize_val_train7_epoch50')  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25843813 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/1F2h4dTE5AEwzXuzoGz7DGAYLmbHrwkX9/MomentCapture/Colab/dataset/categorize/all/data.cache... 313 images, 5 backgrounds, 0 corrupt: 100%|██████████| 314/314 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:29<00:00,  1.50s/it]
#                    all        314       2710      0.899      0.854      0.907      0.706
#               multiple        314       1088      0.926      0.923      0.944       0.87
#       multiple_cropped        314        187       0.96      0.904      0.961      0.874
#             subjective        314        107      0.806      0.972      0.932      0.837
#     subjective_cropped        314         33      0.866      0.667      0.784      0.685
# ...

# %% [markdown]
# ## **비교 train5, train6**
#
# 결론: 데이터를 증강하고 정확도 평가를 했을 때 여전히 epoch는 50일 때가 100일 때보다 낫다.

# %%
from ultralytics.data.utils import autosplit

autosplit(path='../dataset/categorize/all/data', weights=(0.7, 0.3, 0.0))
# Out:
# Autosplitting images from ../dataset/categorize/all/data
# 100%|██████████| 1550/1550 [00:07<00:00, 218.19it/s]

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/categorize_epoch50_train5/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val(data='../dataset/categorize/all/data.yaml', save=False)  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category

# Load a model
model = YOLO('./runs/detect/categorize_epoch100_train6/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val(data='../dataset/categorize/all/data.yaml', save=False)  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25843813 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/1F2h4dTE5AEwzXuzoGz7DGAYLmbHrwkX9/MomentCapture/Colab/dataset/categorize/all/data.cache... 466 images, 8 backgrounds, 0 corrupt: 100%|██████████| 467/467 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 30/30 [00:26<00:00,  1.15it/s]
#                    all        467       3937      0.931      0.889      0.937      0.739
#               multiple        467       1556      0.931      0.914      0.966      0.908
#       multiple_cropped        467        280      0.949      0.968      0.989      0.908
#             subjective        467        165      0.857      0.988      0.966      0.899
#     subjective_cropped        467         57      0.954       0.73      0.861      0.757
# ...

# %% [markdown]
# # **detect**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics/
# Out:
# /content/drive/MyDrive/MomentCapture/Colab/ultralytics

# %%
# !pip install -U ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.2/721.2 kB 4.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **train5 epoch50**

# %% [markdown]
# ### **1**

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/categorize_train5_epoch50/weights/best.pt')  # load a custom model

# Run batched inference on a list of images
results = model(source='../dataset/categorize/all/data', save=True, name='categorize_detect_train5_all', save_crop=True)  # return a generator of Results objects

# Process results generator
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1550 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/all/data/2019_mid_language (1)-1.jpg: 640x480 3 multiples, 2 multiple_croppeds, 4 q_marks, 83.8ms
# ...

# %% [markdown]
# ### **2**

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/categorize_train5_epoch50/weights/best.pt')  # load a custom model

# Run batched inference on a list of images
results = model(source='../dataset/categorize/2022', save=True, name='categorize_detect_train5_rest', save_crop=True)  # return a generator of Results objects

# Process results generator
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
# Out:
# image 1/224 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/2022/2022_suneung (1).jpg: 640x480 4 multiples, 4 q_marks, 29.0ms
# image 2/224 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/2022/2022_suneung (10).jpg: 640x480 2 multiples, 3 q_marks, 28.5ms
# image 3/224 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/2022/2022_suneung (100).jpg: 640x480 2 multiples, 2 q_marks, 42.5ms
# image 4/224 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/2022/2022_suneung (101).jpg: 640x480 4 multiples, 4 q_marks, 28.3ms
# image 5/224 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/2022/2022_suneung (102).jpg: 640x480 2 multiples, 2 q_marks, 28.8ms
# image 6/224 /content/drive/MyDrive/MomentCapture/Colab/ultralytics/../dataset/categorize/2022/2022_suneung (103).jpg: 640x480 6 multiples, 3 q_marks, 28.2ms
# ...

# %% [markdown]
# ## **etc**

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/crop_train1_epoch50/weights/best.pt')  # pretrained YOLOv8n model

# Run batched inference on a list of images
results = model(source='./runs/detect/qna_detect_train2_hagwon/crops/qna', save=True, name='crop_detect_train1_hagwon', save_crop=True)  # return a generator of Results objects

# Process results generator
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-019409dda566> in <cell line: 1>()
# ----> 1 from ultralytics import YOLO
#       2
#       3 # Load a model
#       4 model = YOLO('./runs/detect/crop_train1_epoch50/weights/best.pt')  # pretrained YOLOv8n model
#       5
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/crop_train1_epoch50/weights/best.pt')  # pretrained YOLOv8n model

# Run batched inference on a list of images
results = model(source='../dataset/detect/hagwon', save=True, name='crop_detect_train1_hagwon', save_crop=True)  # return a generator of Results objects

# Process results generator
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs

# %% [markdown]
# # **memo**

# %% [markdown]
# qna > categorize > crop
#
# 이런 과정은 비효율적이고 성능도 안 좋다. 따라서 qna를 감지할 때 주관식 객관식 나누는 쪽으로 ai를 빌딩하는 게 나을 것 같다...
