# %% [markdown]
# # **drive mount**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, sys

my_path = '/content/package'
save_path = '/content/drive/MyDrive/MomentCapture/Colab/package'

os.symlink(save_path, my_path)
sys.path.insert(0, my_path)

# %%
# %pip install ultralytics -target=$my_path
# %pip install easyocr -target=$my_path

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/

# %%
from ultralytics import YOLO

# %%
import easyocr

# %% [markdown]
# # **requirements**

# %%
# %pip install ultralytics -target=$my_path
import ultralytics
ultralytics.checks()

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/package
# !git clone https://github.com/ultralytics/ultralytics.git

# %% [markdown]
# # **train**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/

from ultralytics import YOLO
import easyocr
# Out:
# /content/drive/.shortcut-targets-by-id/1F2h4dTE5AEwzXuzoGz7DGAYLmbHrwkX9/MomentCapture/Colab/ultralytics

# %%
from ultralytics.data.utils import autosplit

autosplit(path='./dataset/subjective/all/data')
# Out:
# Autosplitting images from ../dataset/subjective/all/data
# 100%|██████████| 262/262 [00:01<00:00, 254.23it/s]

# %% [markdown]
# ### **train1**

# %%
from ultralytics.data.utils import autosplit

autosplit(path='./dataset/subjective/all/data')
# Out:
# Autosplitting images from ../dataset/subjective/all/data
# 100%|██████████| 262/262 [00:01<00:00, 170.34it/s]

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')
results = model.train(
    data='./dataset/subjective/all/data.yaml',
    batch=4,
    epochs=50,
    name='subjective_train1_epoch50')
# Out:
# New https://pypi.org/project/ultralytics/8.2.2 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')
results = model.train(
    data='./dataset/subjective/all/data.yaml',
    batch=4,
    epochs=100,
    name='subjective_train1-1_epoch100')
# Out:
# New https://pypi.org/project/ultralytics/8.2.2 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')
results = model.train(
    data='./dataset/subjective/all/data.yaml',
    batch=8,
    epochs=15,
    name='subjective_train1-2_epoch15')
# Out:
# New https://pypi.org/project/ultralytics/8.2.2 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### **train2**

# %%
from ultralytics.data.utils import autosplit

autosplit(path='./dataset/subjective/all/data')

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')
results = model.train(
    data='./dataset/subjective/all/data.yaml',
    batch=4,
    epochs=10,
    name='subjective_train2_epoch10')

# %% [markdown]
# # **transfer train**

# %% [markdown]
# ## **train**

# %%
from ultralytics import YOLO

model = YOLO('./runs/detect/train3_qna_2021-수능_epoch100/weights/best.pt')
results = model.train(
    data='./dataset/crop/data.yaml',
    batch=20,
    epochs=100,
    name='crop_train4_qna_2021-수능_2021-9월_epoch100')

# %% [markdown]
# # **validation**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics/
# !pip install -U ultralytics

from ultralytics import YOLO

# %% [markdown]
# ## **train1**

# %% [markdown]
# 50이랑 100이랑 엄청 큰 성능 차이가 없고 100은 과적합 우려가 있으니 50으로 간다.

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics/
# Out:
# /content/drive/.shortcut-targets-by-id/1F2h4dTE5AEwzXuzoGz7DGAYLmbHrwkX9/MomentCapture/Colab/ultralytics

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/subjective_train1_epoch50/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val(data='./dataset/subjective/all/data.yaml', name='subjective_val_train1')  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients
# val: Scanning /content/drive/.shortcut-targets-by-id/1F2h4dTE5AEwzXuzoGz7DGAYLmbHrwkX9/MomentCapture/Colab/dataset/subjective/all/data.cache... 30 images, 0 backgrounds, 0 corrupt: 100%|██████████| 30/30 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.16s/it]
#                    all         30         51      0.977      0.985      0.995      0.718
#                    num         30         30          1       0.97      0.995      0.666
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/subjective_train1-1_epoch100/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val(data='./dataset/subjective/all/data.yaml', name='subjective_val_train1-1')  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients
# val: Scanning /content/drive/.shortcut-targets-by-id/1F2h4dTE5AEwzXuzoGz7DGAYLmbHrwkX9/MomentCapture/Colab/dataset/subjective/all/data.cache... 30 images, 0 backgrounds, 0 corrupt: 100%|██████████| 30/30 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
#                    all         30         51      0.998      0.969      0.993      0.724
#                    num         30         30      0.995          1      0.995      0.701
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/subjective_train1-2_epoch15/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val(data='./dataset/subjective/all/data.yaml', name='subjective_val_train1-2')  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients
# val: Scanning /content/drive/.shortcut-targets-by-id/1F2h4dTE5AEwzXuzoGz7DGAYLmbHrwkX9/MomentCapture/Colab/dataset/subjective/all/data.cache... 30 images, 0 backgrounds, 0 corrupt: 100%|██████████| 30/30 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.25it/s]
#                    all         30         51      0.995      0.988      0.995      0.673
#                    num         30         30      0.989          1      0.995      0.646
# ...

# %% [markdown]
# ## **train2**

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/subjective_train2_epoch50/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val(data='./dataset/subjective/all/data.yaml', name='subjective_val_train2')  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category

# %% [markdown]
# # **detect**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/MomentCapture/Colab/ultralytics/
# !pip install -U ultralytics

from ultralytics import YOLO

# %% [markdown]
# ## **train1**

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/subjective_train1_epoch50/weights/best.pt')  # pretrained YOLOv8n model

# Run batched inference on a list of images
results = model(source='./dataset/subjective/all/data', save=True, name='subjective_detect_train1_all', save_crop=True)  # return a generator of Results objects

# Process results generator
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs

# %% [markdown]
# ## **train2**

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/train2_qna_2021-수능_2021-9월_epoch50/weights/best.pt')  # pretrained YOLOv8n model

# Run batched inference on a list of images
results = model(source='./dataset/2021_수능/images/detect/', save=True, name='multiple_detect_train2_2021_수능', save_crop=True)  # return a generator of Results objects

# Process results generator
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs

# %% [markdown]
# # **save**

# %%
# !zip -r ../yolo_backup/yolov8_231020.zip ../ultralytics
